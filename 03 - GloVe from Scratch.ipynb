# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
np.__version__, torch.__version__
# Out:
# ('1.26.4', '2.5.1+cu121')

# %%
# Select the GPU with the most free memory
def get_free_gpu():
    # Check if CUDA is available before getting device count
    if torch.cuda.is_available():
        free_mem = [torch.cuda.memory_reserved(i) for i in range(torch.cuda.device_count())]
        return free_mem.index(min(free_mem))
    # If CUDA is not available, return -1 (or another appropriate value)
    else:
        return -1

best_gpu = get_free_gpu()

# Use the best GPU if available, otherwise use CPU
if best_gpu != -1:
    torch.cuda.set_device(best_gpu)
    print(f"Using GPU: {best_gpu}")
else:
    print("No CUDA-enabled GPUs found. Using CPU.")
# Out:
# No CUDA-enabled GPUs found. Using CPU.

# %%
# Set the device variable
device = torch.device(f'cuda:{best_gpu}' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %% [markdown]
# ## 1. Load data

# %%
import nltk
nltk.download('reuters')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.corpus import reuters

# Get sentences from the Reuters corpus
corpus = reuters.sents()

# Limit the corpus to the first 20,000 sentences
corpus = corpus[:10000]
len(corpus)
# Out:
# 10000

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))
vocab
# Out:
# ['ending',
#  'JORDAN',
#  'Sight',
#  'impact',
#  'scratch',
#  'well',
#  'shared',
#  'graphics',
#  'Foothill',
#  'Baldwin',
#  '1965',
#  'channels',
#  'speeds',
#  'WPP',
#  'proportion',
#  'Scallop',
#  'attorney',
#  'WOODSTOCK',
#  'juice',
#  'Distilling',
#  '441',
#  'wound',
#  'Southeast',
#  'Farmer',
#  'raises',
#  'referred',
#  'law',
#  'assessed',
#  'reign',
#  'parities',
#  'multiples',
#  'revealed',
#  'multinational',
#  'CAPE',
#  'GRANTS',
#  'contaminated',
#  'definite',
#  'Hutton',
#  'PARTICIPATING',
#  '367',
#  'According',
#  'programmable',
#  'emphasized',
#  'ALRN',
#  'struggle',
#  'stretch',
#  'MI',
#  'DETAILS',
#  'Stcks',
#  'Fluorocarbon',
#  'parcel',
#  'COATINGS',
#  'CR',
#  'renewal',
#  'UNPREPARED',
#  'whom',
#  'PZA',
#  'separating',
#  'gauges',
#  'priced',
#  'successive',
#  'delivery',
#  'contended',
#  'March',
#  'ASSETS',
#  'Light',
#  'stark',
#  'SHARE',
#  'CEREAL',
#  'Under',
#  'saturated',
#  'dispositions',
#  'fire',
#  'Renato',
#  'emerge',
#  'Clarke',
#  'Piezo',
#  'Electronics',
#  'Postal',
#  'EXTENDS',
#  '553',
#  'nonprofit',
#  'sowing',
#  'gangs',
#  'plateau',
#  'Retail',
#  'tempt',
#  'HARDIE',
#  'imbalanced',
#  'Specific',
#  'failing',
#  'INGOT',
#  'FIRE',
#  'detecting',
#  'indicators',
#  'ELDERS',
#  'INSIDE',
#  'FAILS',
#  '674',
#  'optional',
#  'fare',
#  'ramp',
#  'MTRUS',
#  'TLHT',
#  'Just',
#  'cwt',
#  'incapable',
#  'Brooke',
#  'succeeding',
#  'REHABILITATION',
#  'None',
#  'kill',
#  'soap',
#  'Power',
#  'hwan',
#  'maintains',
#  'Merchants',
#  'former',
#  'swiss',
#  'Hopefully',
#  'eggs',
#  'Comercial',
#  'expertise',
#  'spirits',
#  'Ghent',
#  'Goldfields',
#  'Heublein',
#  '820',
#  'OPERATIVE',
#  'Monobloc',
#  'MINISTRY',
#  'averaged',
#  'watch',
#  'spell',
#  'rules',
#  'Peter',
#  'Construction',
#  'convince',
#  'COMPANIES',
#  'CARRYING',
#  'out',
#  'UND',
#  'Machine',
#  'Chibougamau',
#  'carcinogenic',
#  'TAKING',
#  'des',
#  'managment',
#  'relax',
#  'helpful',
#  'FREE',
#  'SOAR',
#  'lender',
#  'WMPY',
#  'Realistically',
#  'JENNINGS',
#  'ranching',
#  'floor',
#  'UTILITIES',
#  'desperate',
#  'loose',
#  'MEAD',
#  'VENTURE',
#  'tight',
#  'PIONEER',
#  'Computerland',
#  'On',
#  'FUTURES',
#  'Theodor',
#  'Nanfang',
#  'reins',
#  'MARKING',
#  'WURLITZER',
#  'library',
#  'STREET',
#  'Group',
#  'have',
#  '1ST',
#  'Country',
#  'PB',
#  'bail',
#  'edgy',
#  'Amax',
#  'biotechnology',
#  'anywhere',
#  'equaly',
#  'beer',
#  'Two',
#  'economist',
#  'Stowe',
#  'tighter',
#  '186',
#  'threaten',
#  'Monier',
#  'CRUCIBLE',
#  'ORION',
#  'Board',
#  'Cos',
#  'air',
#  'Conger',
#  'BECOME',
#  'revival',
#  'SPI',
#  'consecutive',
#  'raise',
#  'amendment',
#  'Bundebank',
#  'code',
#  'foiled',
#  'Kongsberg',
#  'closes',
#  'education',
#  'authority',
#  'Electronic',
#  'BTP',
#  'Mackoff',
#  '198',
#  'present',
#  'anything',
#  'Compact',
#  'Dalian',
#  'Allies',
#  'inefficiencies',
#  'Corp',
#  'PAYOUT',
#  'inland',
#  'structured',
#  'month',
#  'HONEYWELL',
#  'Wednesday',
#  'Bill',
#  'MAX',
#  'MANUFACTURING',
#  'Greenspan',
#  'sharehoplder',
#  'uncompetitively',
#  'Formula',
#  'MILLION',
#  'recapture',
#  'securitise',
#  'fastest',
#  'EXPIRED',
#  'intelligence',
#  'unrecoverable',
#  'THURSDAY',
#  'Business',
#  'TEXTILE',
#  '289',
#  'lorries',
#  'reacived',
#  'Concerning',
#  'crafting',
#  'sure',
#  'Arthur',
#  '227',
#  'JN',
#  'superfund',
#  'SEEN',
#  'ferrous',
#  'looms',
#  'Khalifa',
#  'SRD',
#  'MARKETING',
#  'dlr',
#  'inviting',
#  'MET',
#  'RUPP',
#  '27',
#  'Maize',
#  'Inchon',
#  'Ed',
#  'fertlizer',
#  'lows',
#  '465',
#  'PREPARES',
#  'Commodities',
#  'KIN',
#  '221',
#  'MEXICO',
#  'Republic',
#  'sugarcane',
#  'threatening',
#  'OFFICE',
#  'tailgates',
#  'Grenfell',
#  'cuts',
#  'Transactions',
#  '724',
#  'BALES',
#  'payout',
#  'disruptive',
#  'Journal',
#  'living',
#  'PHAR',
#  'exasperated',
#  'seriousness',
#  'Ashland',
#  'gasoil',
#  '861',
#  'DETC',
#  'inadequately',
#  'clearances',
#  'Hot',
#  'primes',
#  'viability',
#  'gaurantee',
#  '185',
#  'KUNA',
#  'Import',
#  'percentage',
#  'An',
#  'Centurion',
#  'faces',
#  'bankers',
#  '6226',
#  'LONG',
#  'SPA',
#  'Eurodollar',
#  'CROWNS',
#  'vcs',
#  'MILLER',
#  'SHUTS',
#  '71',
#  'topic',
#  'termination',
#  'MCCL',
#  'HUNGARY',
#  'Rashid',
#  'Schwarz',
#  'Judson',
#  'Maki',
#  'white',
#  '524',
#  'setting',
#  'demonstrating',
#  'Threat',
#  'Minpeco',
#  'watchful',
#  'MacLean',
#  '213',
#  'fertilizer',
#  'LIVING',
#  'visualize',
#  'HTEK',
#  'SUPER',
#  'Cubic',
#  'Affandi',
#  'summit',
#  'Rebates',
#  'surplus',
#  'indication',
#  'potline',
#  'Bavadra',
#  'Bundaberg',
#  'KO',
#  'Percentage',
#  'PURSUE',
#  'identifies',
#  'sacks',
#  'IRVING',
#  'jackup',
#  'Florence',
#  'alluvial',
#  'Plaza',
#  'tension',
#  'PRO',
#  'dismayed',
#  'Thermal',
#  '1A',
#  'R',
#  'Chaco',
#  'RETAIL',
#  'Siemens',
#  'healthy',
#  'Banking',
#  'Fisher',
#  'varying',
#  'substantial',
#  'PRODUCTIONS',
#  'VLSI',
#  'INTERMETCO',
#  'Latin',
#  'LYNCH',
#  'Spa',
#  'Dividend',
#  'accordance',
#  '1983',
#  '350',
#  'rife',
#  'Chew',
#  'adjustments',
#  'Pittsburgh',
#  'overcome',
#  'To',
#  'Udagawa',
#  'DEPENDENCY',
#  'surfacing',
#  'CUTS',
#  'PIPELINES',
#  'BUY',
#  'BERISFORD',
#  'Entre',
#  'CSRA',
#  'Eletrospace',
#  'incoming',
#  'Tyler',
#  'DIPLOMACY',
#  'troubles',
#  'restricting',
#  'crushing',
#  'Liberation',
#  'Stringfellow',
#  'IS',
#  'Complaint',
#  'COUNSEL',
#  'forints',
#  'black',
#  'avalanche',
#  'maintenance',
#  'California',
#  'topped',
#  'Baie',
#  'crumbling',
#  'ENTERED',
#  'SLOWDOWN',
#  'Maghreb',
#  'rubbish',
#  'Decision',
#  'mature',
#  'CSA',
#  'identifed',
#  'favoured',
#  'monetary',
#  'Unloading',
#  'Beverly',
#  'seventh',
#  'Placer',
#  'revises',
#  'cs',
#  'microchip',
#  'DRESSER',
#  '0400',
#  'spares',
#  'sinking',
#  'input',
#  'mandate',
#  '848',
#  'ATTACK',
#  'first',
#  'NER',
#  'east',
#  'availabilities',
#  'ECONOMIC',
#  'riyal',
#  'Unions',
#  'average',
#  'enlargement',
#  'Chemetron',
#  'expanded',
#  'CXR',
#  'maxwell',
#  'performers',
#  'won',
#  'Spie',
#  '451',
#  'toal',
#  'overlook',
#  'pursued',
#  'embraced',
#  'question',
#  'THOMSON',
#  'GRAND',
#  'MICROSYSTEMS',
#  'COUNTRIES',
#  'jitters',
#  'Cay',
#  'CGP',
#  'Sam',
#  'STCH',
#  'BE',
#  'STARTS',
#  'poor',
#  'Renison',
#  'DISPUTE',
#  'STAY',
#  'FINANCIAL',
#  'sixth',
#  'facts',
#  'ASH',
#  '........',
#  'AY',
#  'millets',
#  '691',
#  'Finland',
#  'NYSE',
#  'slowly',
#  '202',
#  'RCA',
#  'MATERIALS',
#  'PUSHING',
#  'Sep',
#  'JARS',
#  'Class',
#  'payment',
#  'an',
#  'NSTC',
#  '1992',
#  'Jaime',
#  'dryness',
#  'WEAR',
#  'localized',
#  'shr',
#  'freedom',
#  'Celanese',
#  'TOTAL',
#  'fed',
#  'subjective',
#  'balance',
#  'REYNOLDS',
#  'Southwestern',
#  'Tom',
#  'MICRO',
#  'Cookeville',
#  'investment',
#  '065',
#  'executed',
#  'CITRUS',
#  'SPRH',
#  'Coastal',
#  'diminishing',
#  'Interest',
#  '201',
#  'If',
#  'MPT',
#  'WSBC',
#  'excludes',
#  'focusing',
#  'debenture',
#  '297',
#  'TEKTRONIX',
#  'teacher',
#  'Cia',
#  'probability',
#  'throw',
#  'WEDNESDAY',
#  'winning',
#  'cranes',
#  'Chapter',
#  'Should',
#  '935',
#  'severance',
#  'seeks',
#  'Agrico',
#  'hold',
#  'cocoa',
#  'Marcus',
#  'Seaforth',
#  'mad',
#  'reflag',
#  'Grieveson',
#  'partisan',
#  'Partnership',
#  'vessels',
#  'Organisation',
#  'Retaliation',
#  '0905',
#  'schedules',
#  'Outlook',
#  'showed',
#  '?,"',
#  'WX',
#  'Ditch',
#  'Camas',
#  'MONOLITHIC',
#  'CSOL',
#  'wants',
#  'flavoring',
#  'Robert',
#  'BPI',
#  'SMG',
#  'cwts',
#  'Terms',
#  'capacities',
#  'supplemental',
#  'disseminated',
#  'tomato',
#  'stayed',
#  'Massachusetts',
#  'lend',
#  'succeeded',
#  'GEODYNAMICS',
#  'KIDS',
#  'Conergic',
#  'Carryover',
#  'government',
#  'Slater',
#  '3267',
#  'automation',
#  'SHAW',
#  '941',
#  '483',
#  'Tradevest',
#  'mellowed',
#  'Delayed',
#  'FULFILLMENT',
#  'commencement',
#  'PGO',
#  'extremely',
#  'WHITE',
#  'Fayetteville',
#  'Arthurs',
#  'MEXICAN',
#  'highly',
#  'win',
#  'RENEGOTIATION',
#  'fabricating',
#  'representations',
#  'STATION',
#  '099',
#  'frequently',
#  'vital',
#  'butane',
#  'slackens',
#  'Spencer',
#  'BSD',
#  'REAL',
#  'Still',
#  'Chilean',
#  'adjourning',
#  'personnel',
#  'often',
#  'GALLONS',
#  'upside',
#  'Chihiro',
#  'Sinhalese',
#  'dark',
#  'sugarbeet',
#  'MICROSEMI',
#  'September',
#  'CONCENTRATE',
#  'reinvest',
#  'Ewing',
#  'registered',
#  'give',
#  'bedding',
#  'Reuters',
#  'Schwietert',
#  'flow',
#  'Refuge',
#  'Suisse',
#  'gander',
#  'appoint',
#  'shiments',
#  'ORIENT',
#  'UNIVERSAL',
#  'Common',
#  'Hibbert',
#  '884',
#  'casualty',
#  'preservation',
#  'Unfortunately',
#  'fall',
#  'Textile',
#  'telecommucations',
#  'expert',
#  'Christian',
#  'Bull',
#  'STEADY',
#  'arranging',
#  'charterer',
#  '124',
#  'Again',
#  'downstream',
#  'bolstered',
#  'sake',
#  'hedged',
#  'CMB',
#  'implied',
#  'GAO',
#  'FEAR',
#  'MICRON',
#  'turning',
#  '386',
#  'establishment',
#  'Storehouse',
#  'why',
#  'slim',
#  '580',
#  'deals',
#  'brought',
#  'Eishiro',
#  'asbestos',
#  'Altogether',
#  'fought',
#  'nationally',
#  'long',
#  'BFI',
#  'Extra',
#  'finance',
#  'accord',
#  'demonstrated',
#  'competitively',
#  'doldrums',
#  'TAXES',
#  'emigration',
#  'dragging',
#  'Honduras',
#  'cook',
#  'displeasure',
#  'DHABI',
#  '298',
#  'Chene',
#  'allowed',
#  'CT',
#  'BANCORP',
#  'Mexican',
#  'MINES',
#  '618',
#  'Final',
#  'Mississippi',
#  'MNTX',
#  'UPPER',
#  'EFFECTIVE',
#  'generally',
#  'defuse',
#  'electronics',
#  'Amadeus',
#  'temperatures',
#  'NGX',
#  'MAKER',
#  'PENTAGON',
#  'acreage',
#  'wildly',
#  'investigating',
#  'prorationing',
#  'warm',
#  'Corporate',
#  'ISCS',
#  'aside',
#  'allocating',
#  'When',
#  'comparison',
#  'MORTGAGE',
#  'disrupted',
#  'Investing',
#  'yearly',
#  'foreseeable',
#  'CALM',
#  'Lyles',
#  'Sept',
#  'KIO',
#  'DBLB',
#  'aides',
#  'commission',
#  '882',
#  'NEEDS',
#  'chile',
#  'enhancer',
#  'Containment',
#  'forestalled',
#  'Rilwanu',
#  'county',
#  'PLANTINGS',
#  'FEBRUARY',
#  'returns',
#  'others',
#  'held',
#  'BRAZIL',
#  'vinyl',
#  'partially',
#  'dent',
#  'entire',
#  'passing',
#  'balances',
#  'frustration',
#  'MTCH',
#  'tools',
#  '415',
#  'formation',
#  'HILLSDOWN',
#  'regards',
#  'COAST',
#  'dependent',
#  '1976',
#  'ROWAN',
#  'mirror',
#  'HEAVY',
#  'document',
#  'quartz',
#  'CRNR',
#  'Wendel',
#  'RIGGS',
#  'INDIANA',
#  'availability',
#  'Cushing',
#  'BB',
#  'Sea',
#  'forecasting',
#  'unevenly',
#  'INDEPENDENCE',
#  'NEw',
#  'Foodstuff',
#  'kilos',
#  'Shintaro',
#  'glut',
#  'outlook',
#  'slaughter',
#  'toured',
#  'Industrielle',
#  '1948',
#  'block',
#  'BOWATER',
#  'mm',
#  'distribute',
#  'CF',
#  'Zealand',
#  'industrialized',
#  'Counties',
#  'ourselves',
#  'overshot',
#  'S',
#  'forceful',
#  'permissible',
#  'Igon',
#  '889',
#  'front',
#  'car',
#  'fat',
#  'Rudman',
#  'Dlr',
#  'ESTIMATES',
#  'annul',
#  'boost',
#  'Metal',
#  'control',
#  'Due',
#  'JBIL',
#  'orchestrated',
#  'insurers',
#  'protest',
#  'inflation',
#  'bank',
#  'aid',
#  'steal',
#  'declaring',
#  'Francisco',
#  'COMMUNICATIONS',
#  'revolution',
#  'JCOR',
#  'lecture',
#  'benefit',
#  'achieved',
#  '1720',
#  'roughly',
#  'deficiency',
#  'gear',
#  'SUL',
#  'redispositions',
#  'part',
#  'insolvent',
#  'REMOVED',
#  'Andriessen',
#  'AUXTON',
#  'jokes',
#  'negatively',
#  'charging',
#  'colombia',
#  'Wales',
#  'dismal',
#  '862',
#  '138',
#  'brewing',
#  'chloride',
#  'working',
#  'shippers',
#  'dollar',
#  'firmly',
#  'anticipate',
#  'RIGS',
#  'hopes',
#  'Canada',
#  'HOMESTAKE',
#  '365',
#  'NEED',
#  'employers',
#  'JUDY',
#  'winnowed',
#  'fur',
#  'TNT',
#  'sharing',
#  'OVER',
#  'mechanical',
#  'AFFILIATES',
#  'Maputo',
#  'crises',
#  'appraisal',
#  'Hamilton',
#  'BELGIAN',
#  'em',
#  'Hisham',
#  'Show',
#  '345',
#  'operator',
#  'Licensing',
#  'Koether',
#  'Dec',
#  'Wynnewood',
#  'domestic',
#  'eyes',
#  'receivable',
#  '931',
#  'imposition',
#  'considerably',
#  'RDC',
#  'LF',
#  'modified',
#  'Akbar',
#  'DOW',
#  'racetrack',
#  'Qtrly',
#  'happier',
#  'regular',
#  'Businessland',
#  'deteriorated',
#  'WHR',
#  'Ord',
#  'moderately',
#  'background',
#  'storm',
#  'generating',
#  'uses',
#  'copper',
#  '291',
#  'platform',
#  'ALL',
#  'grew',
#  'committed',
#  'sony',
#  'promise',
#  'food',
#  'simpler',
#  'Army',
#  'reconvenes',
#  '40',
#  'delivered',
#  '14',
#  'GenCorp',
#  'comply',
#  'photographic',
#  'HKBH',
#  'condtions',
#  'NURSING',
#  'ITEMS',
#  'Mo',
#  'intend',
#  'PRUDENTE',
#  'Rapid',
#  'rout',
#  'INTACT',
#  'NR',
#  'Most',
#  'Bahrain',
#  '?"',
#  'missile',
#  'HOLDERS',
#  'KOAQ',
#  'PROPOSES',
#  'turkey',
#  'powdery',
#  'worldwide',
#  'wouldn',
#  '501',
#  'died',
#  'FINANCE',
#  'BREAKS',
#  'BIOTECH',
#  'disobedience',
#  'INCREASE',
#  'TUNGSTEN',
#  'FGE',
#  'Rose',
#  'resignation',
#  'HERITAGE',
#  'divs',
#  'ERICY',
#  'PLATINUM',
#  'solidarity',
#  'BANKING',
#  'dust',
#  'SUMITA',
#  'Compaq',
#  'Mulroney',
#  'battered',
#  'hailstorms',
#  'ADDITIONAL',
#  'flows',
#  'decreased',
#  'creditor',
#  'metres',
#  'Pakistan',
#  ...]

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'ending': 0, 'JORDAN': 1, 'Sight': 2, 'impact': 3, 'scratch': 4, 'well': 5, 'shared': 6, 'graphics': 7, 'Foothill': 8, 'Baldwin': 9, '1965': 10, 'channels': 11, 'speeds': 12, 'WPP': 13, 'proportion': 14, 'Scallop': 15, 'attorney': 16, 'WOODSTOCK': 17, 'juice': 18, 'Distilling': 19, '441': 20, 'wound': 21, 'Southeast': 22, 'Farmer': 23, 'raises': 24, 'referred': 25, 'law': 26, 'assessed': 27, 'reign': 28, 'parities': 29, 'multiples': 30, 'revealed': 31, 'multinational': 32, 'CAPE': 33, 'GRANTS': 34, 'contaminated': 35, 'definite': 36, 'Hutton': 37, 'PARTICIPATING': 38, '367': 39, 'According': 40, 'programmable': 41, 'emphasized': 42, 'ALRN': 43, 'struggle': 44, 'stretch': 45, 'MI': 46, 'DETAILS': 47, 'Stcks': 48, 'Fluorocarbon': 49, 'parcel': 50, 'COATINGS': 51, 'CR': 52, 'renewal': 53, 'UNPREPARED': 54, 'whom': 55, 'PZA': 56, 'separating': 57, 'gauges': 58, 'priced': 59, 'successive': 60, 'delivery': 61, 'contended': 62, 'March': 63, 'ASSETS': 64, 'Light': 65, 'stark': 66, 'SHARE': 67, 'CEREAL': 68, 'Under': 69, 'saturated': 70, 'dispositions': 71, 'fire': 72, 'Renato': 73, 'emerge': 74, 'Clarke': 75, 'Piezo': 76, 'Electronics': 77, 'Postal': 78, 'EXTENDS': 79, '553': 80, 'nonprofit': 81, 'sowing': 82, 'gangs': 83, 'plateau': 84, 'Retail': 85, 'tempt': 86, 'HARDIE': 87, 'imbalanced': 88, 'Specific': 89, 'failing': 90, 'INGOT': 91, 'FIRE': 92, 'detecting': 93, 'indicators': 94, 'ELDERS': 95, 'INSIDE': 96, 'FAILS': 97, '674': 98, 'optional': 99, 'fare': 100, 'ramp': 101, 'MTRUS': 102, 'TLHT': 103, 'Just': 104, 'cwt': 105, 'incapable': 106, 'Brooke': 107, 'succeeding': 108, 'REHABILITATION': 109, 'None': 110, 'kill': 111, 'soap': 112, 'Power': 113, 'hwan': 114, 'maintains': 115, 'Merchants': 116, 'former': 117, 'swiss': 118, 'Hopefully': 119, 'eggs': 120, 'Comercial': 121, 'expertise': 122, 'spirits': 123, 'Ghent': 124, 'Goldfields': 125, 'Heublein': 126, '820': 127, 'OPERATIVE': 128, 'Monobloc': 129, 'MINISTRY': 130, 'averaged': 131, 'watch': 132, 'spell': 133, 'rules': 134, 'Peter': 135, 'Construction': 136, 'convince': 137, 'COMPANIES': 138, 'CARRYING': 139, 'out': 140, 'UND': 141, 'Machine': 142, 'Chibougamau': 143, 'carcinogenic': 144, 'TAKING': 145, 'des': 146, 'managment': 147, 'relax': 148, 'helpful': 149, 'FREE': 150, 'SOAR': 151, 'lender': 152, 'WMPY': 153, 'Realistically': 154, 'JENNINGS': 155, 'ranching': 156, 'floor': 157, 'UTILITIES': 158, 'desperate': 159, 'loose': 160, 'MEAD': 161, 'VENTURE': 162, 'tight': 163, 'PIONEER': 164, 'Computerland': 165, 'On': 166, 'FUTURES': 167, 'Theodor': 168, 'Nanfang': 169, 'reins': 170, 'MARKING': 171, 'WURLITZER': 172, 'library': 173, 'STREET': 174, 'Group': 175, 'have': 176, '1ST': 177, 'Country': 178, 'PB': 179, 'bail': 180, 'edgy': 181, 'Amax': 182, 'biotechnology': 183, 'anywhere': 184, 'equaly': 185, 'beer': 186, 'Two': 187, 'economist': 188, 'Stowe': 189, 'tighter': 190, '186': 191, 'threaten': 192, 'Monier': 193, 'CRUCIBLE': 194, 'ORION': 195, 'Board': 196, 'Cos': 197, 'air': 198, 'Conger': 199, 'BECOME': 200, 'revival': 201, 'SPI': 202, 'consecutive': 203, 'raise': 204, 'amendment': 205, 'Bundebank': 206, 'code': 207, 'foiled': 208, 'Kongsberg': 209, 'closes': 210, 'education': 211, 'authority': 212, 'Electronic': 213, 'BTP': 214, 'Mackoff': 215, '198': 216, 'present': 217, 'anything': 218, 'Compact': 219, 'Dalian': 220, 'Allies': 221, 'inefficiencies': 222, 'Corp': 223, 'PAYOUT': 224, 'inland': 225, 'structured': 226, 'month': 227, 'HONEYWELL': 228, 'Wednesday': 229, 'Bill': 230, 'MAX': 231, 'MANUFACTURING': 232, 'Greenspan': 233, 'sharehoplder': 234, 'uncompetitively': 235, 'Formula': 236, 'MILLION': 237, 'recapture': 238, 'securitise': 239, 'fastest': 240, 'EXPIRED': 241, 'intelligence': 242, 'unrecoverable': 243, 'THURSDAY': 244, 'Business': 245, 'TEXTILE': 246, '289': 247, 'lorries': 248, 'reacived': 249, 'Concerning': 250, 'crafting': 251, 'sure': 252, 'Arthur': 253, '227': 254, 'JN': 255, 'superfund': 256, 'SEEN': 257, 'ferrous': 258, 'looms': 259, 'Khalifa': 260,  ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 18045

# %%
#append UNK
vocab.append('<UNK>')

# %%
vocab[:100]
# Out:
# ['ending',
#  'JORDAN',
#  'Sight',
#  'impact',
#  'scratch',
#  'well',
#  'shared',
#  'graphics',
#  'Foothill',
#  'Baldwin',
#  '1965',
#  'channels',
#  'speeds',
#  'WPP',
#  'proportion',
#  'Scallop',
#  'attorney',
#  'WOODSTOCK',
#  'juice',
#  'Distilling',
#  '441',
#  'wound',
#  'Southeast',
#  'Farmer',
#  'raises',
#  'referred',
#  'law',
#  'assessed',
#  'reign',
#  'parities',
#  'multiples',
#  'revealed',
#  'multinational',
#  'CAPE',
#  'GRANTS',
#  'contaminated',
#  'definite',
#  'Hutton',
#  'PARTICIPATING',
#  '367',
#  'According',
#  'programmable',
#  'emphasized',
#  'ALRN',
#  'struggle',
#  'stretch',
#  'MI',
#  'DETAILS',
#  'Stcks',
#  'Fluorocarbon',
#  'parcel',
#  'COATINGS',
#  'CR',
#  'renewal',
#  'UNPREPARED',
#  'whom',
#  'PZA',
#  'separating',
#  'gauges',
#  'priced',
#  'successive',
#  'delivery',
#  'contended',
#  'March',
#  'ASSETS',
#  'Light',
#  'stark',
#  'SHARE',
#  'CEREAL',
#  'Under',
#  'saturated',
#  'dispositions',
#  'fire',
#  'Renato',
#  'emerge',
#  'Clarke',
#  'Piezo',
#  'Electronics',
#  'Postal',
#  'EXTENDS',
#  '553',
#  'nonprofit',
#  'sowing',
#  'gangs',
#  'plateau',
#  'Retail',
#  'tempt',
#  'HARDIE',
#  'imbalanced',
#  'Specific',
#  'failing',
#  'INGOT',
#  'FIRE',
#  'detecting',
#  'indicators',
#  'ELDERS',
#  'INSIDE',
#  'FAILS',
#  '674',
#  'optional']

# %%
word2index['<UNK>'] = voc_size

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 18046

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus))
X_i
# Out:
# Counter({'ASIAN': 2,
#          'EXPORTERS': 14,
#          'FEAR': 1,
#          'DAMAGE': 1,
#          'FROM': 24,
#          'U': 1115,
#          '.': 18486,
#          'S': 1138,
#          '.-': 42,
#          'JAPAN': 67,
#          'RIFT': 1,
#          'Mounting': 1,
#          'trade': 397,
#          'friction': 8,
#          'between': 188,
#          'the': 10442,
#          'And': 44,
#          'Japan': 373,
#          'has': 934,
#          'raised': 64,
#          'fears': 11,
#          'among': 35,
#          'many': 41,
#          'of': 6525,
#          'Asia': 14,
#          "'": 2087,
#          's': 1709,
#          'exporting': 12,
#          'nations': 66,
#          'that': 1347,
#          'row': 3,
#          'could': 283,
#          'inflict': 1,
#          'far': 45,
#          '-': 2741,
#          'reaching': 7,
#          'economic': 189,
#          'damage': 27,
#          ',': 12956,
#          'businessmen': 14,
#          'and': 4478,
#          'officials': 156,
#          'said': 4626,
#          'They': 124,
#          'told': 237,
#          'Reuter': 11,
#          'correspondents': 3,
#          'in': 4589,
#          'Asian': 11,
#          'capitals': 3,
#          'a': 4082,
#          'Move': 1,
#          'against': 252,
#          'might': 57,
#          'boost': 43,
#          'protectionist': 22,
#          'sentiment': 10,
#          'lead': 87,
#          'to': 5873,
#          'curbs': 10,
#          'on': 1529,
#          'American': 105,
#          'imports': 171,
#          'their': 229,
#          'products': 177,
#          'But': 221,
#          'some': 229,
#          'exporters': 35,
#          'while': 140,
#          'conflict': 3,
#          'would': 918,
#          'hurt': 6,
#          'them': 58,
#          'long': 114,
#          'run': 17,
#          'short': 75,
#          'term': 105,
#          'Tokyo': 59,
#          'loss': 539,
#          'be': 1148,
#          'gain': 94,
#          'The': 2045,
#          'Has': 7,
#          'it': 1567,
#          'will': 961,
#          'impose': 18,
#          '300': 86,
#          'mln': 2958,
#          'dlrs': 1988,
#          'tariffs': 63,
#          'Japanese': 183,
#          'electronics': 17,
#          'goods': 68,
#          'April': 438,
#          '17': 189,
#          'retaliation': 19,
#          'for': 2384,
#          'alleged': 11,
#          'failure': 22,
#          'stick': 1,
#          'pact': 50,
#          'not': 807,
#          'sell': 104,
#          'semiconductors': 9,
#          'world': 125,
#          'markets': 164,
#          'at': 1236,
#          'below': 64,
#          'cost': 82,
#          'Unofficial': 1,
#          'estimates': 45,
#          'put': 55,
#          'impact': 51,
#          '10': 435,
#          'billion': 1080,
#          'spokesmen': 3,
#          'major': 190,
#          'firms': 49,
#          'they': 394,
#          'virtually': 13,
#          'halt': 10,
#          'exports': 191,
#          'hit': 32,
#          'by': 1318,
#          'new': 275,
#          'taxes': 27,
#          '"': 1245,
#          'We': 115,
#          'wouldn': 6,
#          't': 75,
#          'able': 31,
#          'do': 89,
#          'business': 144,
#          ',"': 658,
#          'spokesman': 159,
#          'leading': 45,
#          'firm': 86,
#          'Matsushita': 1,
#          'Electric': 20,
#          'Industrial': 20,
#          'Co': 297,
#          'Ltd': 252,
#          '&': 1497,
#          'lt': 1498,
#          ';': 1503,
#          'MC': 1,
#          'T': 38,
#          '>.': 74,
#          'If': 47,
#          'remain': 53,
#          'place': 31,
#          'any': 136,
#          'length': 1,
#          'time': 139,
#          'beyond': 12,
#          'few': 41,
#          'months': 159,
#          'mean': 11,
#          'complete': 21,
#          'erosion': 2,
#          '(': 565,
#          'subject': 72,
#          ')': 420,
#          '.,"': 5,
#          'Tom': 4,
#          'Murtha': 1,
#          'stock': 353,
#          'analyst': 56,
#          'office': 23,
#          'broker': 18,
#          'James': 30,
#          'Capel': 2,
#          'In': 261,
#          'Taiwan': 53,
#          'are': 624,
#          'also': 436,
#          'worried': 13,
#          'aware': 7,
#          'seriousness': 3,
#          'Threat': 1,
#          'because': 208,
#          'serves': 3,
#          'as': 806,
#          'warning': 4,
#          'us': 30,
#          'senior': 35,
#          'Taiwanese': 4,
#          'official': 137,
#          'who': 98,
#          'asked': 51,
#          'named': 21,
#          'had': 509,
#          'surplus': 140,
#          '15': 317,
#          '6': 696,
#          'last': 613,
#          'year': 1090,
#          '95': 74,
#          'pct': 1696,
#          'with': 1085,
#          'helped': 20,
#          'swell': 2,
#          'foreign': 217,
#          'exchange': 171,
#          'reserves': 126,
#          '53': 54,
#          'largest': 79,
#          'must': 42,
#          'quickly': 18,
#          'open': 88,
#          'our': 90,
#          'remove': 9,
#          'barriers': 11,
#          'cut': 179,
#          'import': 59,
#          'allow': 40,
#          'Products': 16,
#          'if': 231,
#          'we': 143,
#          'want': 43,
#          'defuse': 2,
#          'problems': 50,
#          'from': 1342,
#          'possible': 72,
#          'Retaliation': 1,
#          'Paul': 21,
#          'Sheen': 1,
#          'chairman': 113,
#          'textile': 20,
#          'Safe': 1,
#          'Group': 127,
#          'A': 328,
#          'South': 107,
#          'Korea': 41,
#          'promotion': 3,
#          'association': 13,
#          'dispute': 20,
#          'pressure': 55,
#          'whose': 21,
#          'chief': 49,
#          'similar': 36,
#          'those': 73,
#          'Last': 35,
#          '7': 682,
#          '1': 1836,
#          '.,': 104,
#          'Up': 2,
#          '4': 872,
#          '9': 548,
#          '1985': 290,
#          'Malaysia': 18,
#          'officers': 16,
#          'tough': 23,
#          'hard': 31,
#          'producers': 60,
#          'third': 62,
#          'countries': 135,
#          'expand': 23,
#          'sales': 230,
#          'Hong': 21,
#          'Kong': 21,
#          'where': 55,
#          'newspapers': 5,
#          'have': 540,
#          'been': 396,
#          'selling': 38,
#          'manufacturers': 10,
#          'share': 466,
#          'view': 39,
#          'other': 293,
#          'such': 93,
#          'commercial': 28,
#          'advantage': 8,
#          'outweighed': 2,
#          'further': 160,
#          'Pressure': 2,
#          'block': 11,
#          'That': 29,
#          'is': 1404,
#          'very': 70,
#          'Lawrence': 2,
#          'Mills': 6,
#          'director': 34,
#          'general': 37,
#          'Federation': 17,
#          'Industry': 40,
#          'whole': 20,
#          'purpose': 9,
#          'prevent': 29,
#          'one': 452,
#          'day': 113,
#          'extended': 16,
#          'sources': 152,
#          'Much': 4,
#          'more': 329,
#          'serious': 13,
#          'disadvantage': 2,
#          'action': 76,
#          'restraining': 2,
#          'he': 690,
#          'was': 1123,
#          'biggest': 24,
#          'export': 112,
#          'market': 448,
#          'accounting': 23,
#          'over': 221,
#          '30': 355,
#          'domestically': 5,
#          'produced': 45,
#          'Australian': 44,
#          'government': 280,
#          'awaiting': 9,
#          'outcome': 12,
#          'talks': 89,
#          'interest': 222,
#          'concern': 36,
#          'Minister': 93,
#          'John': 23,
#          'Button': 2,
#          'Canberra': 1,
#          'Friday': 44,
#          'This': 99,
#          'kind': 13,
#          'deterioration': 5,
#          'relations': 12,
#          'two': 409,
#          'which': 641,
#          'trading': 129,
#          'partners': 31,
#          'ours': 2,
#          'matter': 16,
#          'He': 275,
#          'Australia': 46,
#          'concerns': 9,
#          'centred': 1,
#          'coal': 7,
#          'beef': 52,
#          'significant': 34,
#          'Exports': 85,
#          'country': 91,
#          'Meanwhile': 7,
#          'diplomatic': 6,
#          'manoeuvres': 1,
#          'solve': 4,
#          'stand': 12,
#          'off': 79,
#          'continue': 81,
#          'ruling': 30,
#          'Liberal': 13,
#          'Democratic': 17,
#          'Party': 16,
#          'yesterday': 139,
#          'outlined': 12,
#          'package': 33,
#          'measures': 64,
#          'economy': 117,
#          'proposed': 103,
#          'include': 63,
#          'large': 68,
#          'supplementary': 5,
#          'budget': 95,
#          'record': 120,
#          'public': 71,
#          'works': 10,
#          'spending': 49,
#          'first': 325,
#          'half': 105,
#          'financial': 102,
#          'call': 20,
#          'stepped': 2,
#          'up': 345,
#          'an': 809,
#          'emergency': 8,
#          'measure': 16,
#          'stimulate': 27,
#          'despite': 61,
#          'Prime': 26,
#          'Yasuhiro': 12,
#          'Nakasone': 22,
#          'avowed': 1,
#          'fiscal': 89,
#          'reform': 26,
#          'program': 52,
#          'Deputy': 11,
#          'Trade': 86,
#          'Representative': 12,
#          'Michael': 12,
#          'Smith': 11,
#          'Makoto': 3,
#          'Kuroda': 9,
#          'deputy': 5,
#          'minister': 23,
#          'International': 140,
#          'MITI': 17,
#          '),': 83,
#          'due': 156,
#          'meet': 59,
#          'Washington': 89,
#          'this': 539,
#          'week': 314,
#          'effort': 28,
#          'end': 212,
#          'CHINA': 22,
#          'DAILY': 5,
#          'SAYS': 125,
#          'VERMIN': 1,
#          'EAT': 1,
#          '12': 258,
#          'PCT': 115,
#          'GRAIN': 40,
#          'STOCKS': 14,
#          'survey': 7,
#          '19': 182,
#          'provinces': 6,
#          'seven': 112,
#          'cities': 4,
#          'showed': 48,
#          'vermin': 1,
#          'consume': 3,
#          'China': 84,
#          'grain': 73,
#          'stocks': 69,
#          'Daily': 25,
#          'It': 369,
#          'each': 109,
#          '575': 7,
#          'tonnes': 501,
#          'or': 551,
#          '25': 247,
#          'fruit': 3,
#          'output': 85,
#          'left': 28,
#          'rot': 1,
#          '2': 1306,
#          'its': 1350,
#          'vegetables': 4,
#          'paper': 24,
#          'blamed': 6,
#          'waste': 8,
#          'inadequate': 10,
#          'storage': 14,
#          'bad': 5,
#          'preservation': 2,
#          'methods': 6,
#          'launched': 20,
#          'national': 44,
#          'programme': 13,
#          'reduce': 75,
#          'calling': 10,
#          'improved': 39,
#          'technology': 21,
#          'greater': 21,
#          'production': 210,
#          'additives': 2,
#          'gave': 44,
#          'no': 229,
#          'details': 44,
#          'TO': 442,
#          'REVISE': 2,
#          'LONG': 4,
#          'TERM': 12,
#          'ENERGY': 9,
#          'DEMAND': 17,
#          'DOWNWARDS': 1,
#          'Ministry': 62,
#          'revise': 6,
#          'energy': 48,
#          'supply': 108,
#          '/': 1612,
#          'demand': 155,
#          'outlook': 23,
#          'August': 39,
#          'forecast': 90,
#          'downtrend': 2,
#          'ministry': 43,
#          'expected': 265,
#          'lower': 140,
#          'projection': 6,
#          'primary': 26,
#          'supplies': 56,
#          '2000': 7,
#          '550': 13,
#          'kilolitres': 1,
#          'kl': 1,
#          '600': 58,
#          'decision': 62,
#          'follows': 45,
#          'emergence': 1,
#          'structural': 8,
#          'changes': 38,
#          'industry': 151,
#          'following': 64,
#          'rise': 201,
#          'value': 105,
#          'yen': 175,
#          'decline': 73,
#          'domestic': 127,
#          'electric': 4,
#          'power': 24,
#          'planning': 12,
#          'work': 36,
#          'out': 138,
#          'revised': 43,
#          'through': 119,
#          'deliberations': 1,
#          'committee': 45,
#          'meetings': 29,
#          'Agency': 18,
#          'Natural': 9,
#          'Resources': 27,
#          'Energy': 36,
#          'review': 32,
#          'breakdown': 7,
#          'including': 99,
#          'oil': 421,
#          'nuclear': 1,
#          'natural': 37,
#          'gas': 116,
#          'Nuclear': 1,
#          'provided': 25,
#          'bulk': 15,
#          'ended': 140,
#          'March': 258,
#          '31': 228,
#          'supplying': 5,
#          'estimated': 105,
#          '27': 122,
#          'kilowatt': 1,
#          'hour': 10,
#          'basis': 67,
#          'followed': 23,
#          '23': 153,
#          'liquefied': 3,
#          '21': 139,
#          'noted': 61,
#          'THAI': 6,
#          'TRADE': 66,
#          'DEFICIT': 21,
#          'WIDENS': 3,
#          'IN': 220,
#          'FIRST': 62,
#          'QUARTER': 25,
#          'Thailand': 23,
#          'deficit': 190,
#          'widened': 6,
#          '5': 883,
#          'baht': 3,
#          'quarter': 348,
#          '1987': 459,
#          'ago': 122,
#          'Business': 14,
#          'Economics': 6,
#          'Department': 119,
#          'Janunary': 1,
#          'rose': 209,
#          '65': 78,
#          '58': 72,
#          'climate': 4,
#          'resulted': 20,
#          'increase': 216,
#          'raw': 19,
#          'materials': 35,
#          'semi': 10,
#          'finished': 6,
#          'bill': 48,
#          'however': 55,
#          'fell': 122,
#          'prices': 333,
#          'department': 60,
#          'expanded': 7,
#          '60': 134,
#          '56': 52,
#          'Export': 26,
#          'growth': 227,
#          'smaller': 17,
#          'than': 364,
#          'earnings': 157,
#          'key': 45,
#          'commodities': 27,
#          'rice': 50,
#          'declined': 61,
#          '18': 204,
#          'maize': 27,
#          '66': 56,
#          'sugar': 92,
#          '45': 95,
#          'tin': 28,
#          '26': 104,
#          'canned': 4,
#          'pineapples': 1,
#          'registering': 3,
#          'high': 129,
#          'were': 595,
#          'jewellery': 1,
#          '64': 52,
#          'clothing': 4,
#          '57': 44,
#          'rubber': 23,
#          '35': 137,
#          'INDONESIA': 8,
#          'SEES': 56,
#          'CPO': 5,
#          'PRICE': 35,
#          'RISING': 5,
#          'SHARPLY': 9,
#          'Indonesia': 38,
#          'expects': 88,
#          'crude': 99,
#          'palm': 26,
#          'sharply': 37,
#          '450': 28,
#          'tonne': 73,
#          'FOB': 10,
#          'sometime': 3,
#          'better': 40,
#          'European': 114,
#          'fall': 96,
#          'Malaysian': 10,
#          'Hasrul': 1,
#          'Harahap': 3,
#          'junior': 4,
#          'tree': 2,
#          'crops': 28,
#          'Indonesian': 8,
#          'reporters': 47,
#          'Prices': 5,
#          'Sumatran': 1,
#          'now': 150,
#          'around': 159,
#          '332': 7,
#          'CIF': 3,
#          'delivery': 51,
#          'Rotterdam': 11,
#          'traders': 102,
#          'maintain': 37,
#          'making': 70,
#          'recent': 98,
#          'purchases': 32,
#          'so': 96,
#          'possibly': 19,
#          'international': 62,
#          'second': 76,
#          'producer': 51,
#          'after': 335,
#          'forced': 16,
#          'ensure': 9,
#          'during': 98,
#          'Moslem': 1,
#          'fasting': 2,
#          'month': 248,
#          'Ramadan': 2,
#          'cover': 28,
#          'temporary': 23,
#          'shortage': 18,
#          'lose': 7,
#          'calendar': 18,
#          '1986': 849,
#          '530': 4,
#          '500': 127,
#          '468': 5,
#          'according': 41,
#          'central': 140,
#          'bank': 233,
#          'figures': 112,
#          'AUSTRALIAN': 12,
#          'FOREIGN': 10,
#          'SHIP': 4,
#          'BAN': 5,
#          'ENDS': 6,
#          'BUT': 4,
#          'NSW': 10,
#          'PORTS': 1,
#          'HIT': 5,
#          'Tug': 2,
#          'crews': 3,
#          'New': 158,
#          'Wales': 5,
#          'Victoria': 3,
#          'Western': 47,
#          'lifted': 14,
#          'ban': 16,
#          'flag': 9,
#          'ships': 33,
#          'carrying': 11,
#          'containers': 2,
#          'but': 425,
#          'ports': 17,
#          'still': 105,
#          'being': 97,
#          'disrupted': 7,
#          'separate': 19,
#          'shipping': 21,
#          'imposed': 25,
#          'pay': 70,
#          'claim': 7,
#          'prevented': 7,
#          'movement': 19,
#          'port': 40,
#          'nearly': 32,
#          '20': 331,
#          'vessels': 20,
#          'went': 25,
#          'before': 140,
#          'hearing': 13,
#          'Arbitration': 2,
#          'Commission': 99,
#          'today': 251,
#          'disruption': 3,
#          'began': 46,
#          'cargo': 16,
#          'handling': 7,
#          'Sydney': 5,
#          'Newcastle': 3,
#          'Port': 7,
#          'Kembla': 3,
#          'industrial': 88,
#          'part': 92,
#          'called': 60,
#          'Trades': 4,
#          'Labour': 8,
#          'Council': 42,
#          'protest': 7,
#          'state': 79,
#          'workers': 48,
#          'compensation': 12,
#          'laws': 14,
#          'various': 19,
#          'unions': 7,
#          'appear': 16,
#          'taking': 35,
#          'turn': 12,
#          'start': 43,
#          'shift': 10,
#          'then': 42,
#          'walk': 1,
#          'Cargo': 2,
#          'container': 4,
#          'movements': 9,
#          'most': 88,
#          'affected': 36,
#          'stopped': 9,
#          'altogether': 3,
#          'say': 87,
#          'how': 40,
#          'go': 39,
#          'what': 70,
#          'effect': 45,
#          'INDONESIAN': 2,
#          'COMMODITY': 2,
#          'EXCHANGE': 12,
#          'MAY': 75,
#          'EXPAND': 2,
#          'Commodity': 23,
#          'Exchange': 96,
#          'likely': 101,
#          'least': 45,
#          'commodity': 24,
#          'Paian': 1,
#          'Nainggolan': 3,
#          'Reuters': 91,
#          'telephone': 20,
#          'interview': 22,
#          'sawn': 1,
#          'timber': 5,
#          'pepper': 1,
#          'tobacco': 14,
#          'considered': 20,
#          'Trading': 8,
#          'either': 22,
#          'refined': 22,
#          'may': 156,
#          'introduced': 23,
#          'question': 19,
#          'Rachmat': 1,
#          'Saleh': 2,
#          'when': 159,
#          'ahead': 27,
#          'made': 174,
#          'fledgling': 1,
#          'currently': 54,
#          'trades': 10,
#          'coffee': 47,
#          'physicals': 2,
#          'outcry': 1,
#          'system': 74,
#          'four': 161,
#          'days': 124,
#          'Several': 7,
#          'factors': 30,
#          'make': 82,
#          'move': 98,
#          'cautiously': 2,
#          'slowly': 6,
#          'safely': 1,
#          'mistake': 2,
#          'undermine': 5,
#          'confidence': 21,
#          '."': 297,
#          'Physical': 1,
#          'added': 218,
#          'January': 96,
#          'Rubber': 9,
#          'contracts': 41,
#          'traded': 27,
#          'five': 219,
#          'forward': 29,
#          'Robusta': 1,
#          'grades': 15,
#          'prompt': 2,
#          'board': 137,
#          'considering': 27,
#          'introduction': 10,
#          'futures': 50,
#          'later': 54,
#          'feasibility': 3,
#          'study': 23,
#          'needed': 50,
#          'No': 25,
#          'decisions': 13,
#          'until': 58,
#          'elections': 6,
#          'Monday': 25,
#          'should': 140,
#          'marketing': 47,
#          'hoped': 14,
#          'development': 54,
#          'help': 74,
#          'trying': 26,
#          'overseas': 18,
#          'building': 30,
#          'contacts': 5,
#          'users': 7,
#          'teams': 1,
#          'already': 82,
#          'encourage': 17,
#          'direct': 13,
#          'use': 61,
#          'delegation': 9,
#          'visit': 17,
#          'Europe': 42,
#          'Mexico': 20,
#          'Latin': 4,
#          'states': 33,
#          'participation': 7,
#          'Officials': 32,
#          'infant': 1,
#          'good': 65,
#          'although': 50,
#          'disappointing': 4,
#          'Transactions': 1,
#          'December': 86,
#          'totalled': 26,
#          '595': 5,
#          'worth': 48,
#          'plus': 32,
#          '184': 9,
#          '3': 903,
#          'rupiah': 3,
#          'delivered': 9,
#          'locally': 2,
#          'latest': 57,
#          'report': 174,
#          'amounted': 6,
#          'only': 171,
#          '905': 8,
#          '381': 6,
#          'lots': 4,
#          'valued': 15,
#          '87': 592,
#          'Total': 90,
#          'membership': 8,
#          'nine': 75,
#          'brokers': 18,
#          '44': 53,
#          'SRI': 4,
#          'LANKA': 3,
#          'GETS': 8,
#          'USDA': 108,
#          'APPROVAL': 3,
#          'FOR': 158,
#          'WHEAT': 45,
#          'Food': 11,
#          'Agriculture': 116,
#          'approved': 57,
#          'Continental': 21,
#          'Grain': 17,
#          'sale': 126,
#          '52': 76,
#          'soft': 20,
#          'wheat': 132,
#          '89': 41,
#          'Dlrs': 31,
#          'C': 70,
#          'F': 48,
#          'Pacific': 30,
#          'Northwest': 4,
#          'Colombo': 5,
#          'shipment': 32,
#          '8': 653,
#          'WESTERN': 10,
#          'MINING': 9,
#          'OPEN': 10,
#          'NEW': 40,
#          'GOLD': 18,
#          'MINE': 5,
#          'AUSTRALIA': 9,
#          'Mining': 20,
#          'Corp': 449,
#          'Holdings': 31,
#          'WMNG': 2,
#          '>': 1271,
#          'WMC': 6,
#          'establish': 5,
#          'joint': 52,
#          'venture': 36,
#          'gold': 67,
#          'mine': 43,
#          'Northern': 5,
#          'Territory': 2,
#          'about': 496,
#          'known': 23,
#          'Goodall': 1,
#          'project': 11,
#          'owned': 122,
#          '40': 150,
#          'local': 51,
#          'W': 17,
#          'R': 17,
#          'Grace': 9,
#          'GRA': 3,
#          'unit': 95,
#          'located': 15,
#          'kms': 2,
#          'east': 18,
#          'Adelaide': 1,
#          'River': 13,
#          'Mt': 1,
#          'Bundey': 1,
#          'statement': 165,
#          'pit': 2,
#          'conventional': 3,
#          'leach': 1,
#          'treatment': 9,
#          'plant': 55,
#          'produce': 27,
#          '50': 358,
#          '000': 1605,
#          'ounces': 17,
#          'mid': 23,
#          '1988': 87,
#          'Annual': 2,
#          'ore': 17,
#          'capacity': 42,
#          '750': 18,
#          'SUMITOMO': 1,
#          'BANK': 94,
#          'AIMS': 1,
#          'AT': 37,
#          'QUICK': 1,
#          'RECOVERY': 5,
#          'MERGER': 26,
#          'Sumitomo': 15,
#          'Bank': 289,
#          'SUMI': 1,
#          'certain': 61,
#          'status': 14,
#          'profitable': 21,
#          'result': 86,
#          'merger': 102,
#          'Heiwa': 4,
#          'Sogo': 4,
#          'analysts': 138,
#          'Osaka': 2,
#          'based': 128,
#          'desposits': 1,
#          'trillion': 4,
#          'merged': 6,
#          'small': 36,
#          'struggling': 3,
#          '29': 106,
#          'unrecoverable': 1,
#          'loans': 82,
#          'October': 52,
#          'link': 10,
#          'President': 63,
#          'Koh': 1,
#          'Komatsu': 9,
#          'confident': 9,
#          'his': 101,
#          'can': 112,
#          'regain': 1,
#          'position': 64,
#          'll': 4,
#          'back': 49,
#          'within': 61,
#          'three': 260,
#          'years': 154,
#          'initially': 8,
#          'profitability': 5,
#          'efficiency': 8,
#          ...})

# %%
skip_grams = []
window_size = 2

for doc in corpus:
    for i in range(window_size, len(doc)-window_size):
        center = doc[i]
        # outside = [doc[i-1], doc[i+1]]
        outside = tuple(doc[j] for j in range(i - window_size, i + window_size + 1) if j != i)
        for each_out in outside:
            skip_grams.append((center, each_out))
skip_grams
# Out:
# [('FEAR', 'ASIAN'),
#  ('FEAR', 'EXPORTERS'),
#  ('FEAR', 'DAMAGE'),
#  ('FEAR', 'FROM'),
#  ('DAMAGE', 'EXPORTERS'),
#  ('DAMAGE', 'FEAR'),
#  ('DAMAGE', 'FROM'),
#  ('DAMAGE', 'U'),
#  ('FROM', 'FEAR'),
#  ('FROM', 'DAMAGE'),
#  ('FROM', 'U'),
#  ('FROM', '.'),
#  ('U', 'DAMAGE'),
#  ('U', 'FROM'),
#  ('U', '.'),
#  ('U', 'S'),
#  ('.', 'FROM'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.-'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.-'),
#  ('S', 'JAPAN'),
#  ('.-', '.'),
#  ('.-', 'S'),
#  ('.-', 'JAPAN'),
#  ('.-', 'RIFT'),
#  ('JAPAN', 'S'),
#  ('JAPAN', '.-'),
#  ('JAPAN', 'RIFT'),
#  ('JAPAN', 'Mounting'),
#  ('RIFT', '.-'),
#  ('RIFT', 'JAPAN'),
#  ('RIFT', 'Mounting'),
#  ('RIFT', 'trade'),
#  ('Mounting', 'JAPAN'),
#  ('Mounting', 'RIFT'),
#  ('Mounting', 'trade'),
#  ('Mounting', 'friction'),
#  ('trade', 'RIFT'),
#  ('trade', 'Mounting'),
#  ('trade', 'friction'),
#  ('trade', 'between'),
#  ('friction', 'Mounting'),
#  ('friction', 'trade'),
#  ('friction', 'between'),
#  ('friction', 'the'),
#  ('between', 'trade'),
#  ('between', 'friction'),
#  ('between', 'the'),
#  ('between', 'U'),
#  ('the', 'friction'),
#  ('the', 'between'),
#  ('the', 'U'),
#  ('the', '.'),
#  ('U', 'between'),
#  ('U', 'the'),
#  ('U', '.'),
#  ('U', 'S'),
#  ('.', 'the'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.'),
#  ('S', 'And'),
#  ('.', '.'),
#  ('.', 'S'),
#  ('.', 'And'),
#  ('.', 'Japan'),
#  ('And', 'S'),
#  ('And', '.'),
#  ('And', 'Japan'),
#  ('And', 'has'),
#  ('Japan', '.'),
#  ('Japan', 'And'),
#  ('Japan', 'has'),
#  ('Japan', 'raised'),
#  ('has', 'And'),
#  ('has', 'Japan'),
#  ('has', 'raised'),
#  ('has', 'fears'),
#  ('raised', 'Japan'),
#  ('raised', 'has'),
#  ('raised', 'fears'),
#  ('raised', 'among'),
#  ('fears', 'has'),
#  ('fears', 'raised'),
#  ('fears', 'among'),
#  ('fears', 'many'),
#  ('among', 'raised'),
#  ('among', 'fears'),
#  ('among', 'many'),
#  ('among', 'of'),
#  ('many', 'fears'),
#  ('many', 'among'),
#  ('many', 'of'),
#  ('many', 'Asia'),
#  ('of', 'among'),
#  ('of', 'many'),
#  ('of', 'Asia'),
#  ('of', "'"),
#  ('Asia', 'many'),
#  ('Asia', 'of'),
#  ('Asia', "'"),
#  ('Asia', 's'),
#  ("'", 'of'),
#  ("'", 'Asia'),
#  ("'", 's'),
#  ("'", 'exporting'),
#  ('s', 'Asia'),
#  ('s', "'"),
#  ('s', 'exporting'),
#  ('s', 'nations'),
#  ('exporting', "'"),
#  ('exporting', 's'),
#  ('exporting', 'nations'),
#  ('exporting', 'that'),
#  ('nations', 's'),
#  ('nations', 'exporting'),
#  ('nations', 'that'),
#  ('nations', 'the'),
#  ('that', 'exporting'),
#  ('that', 'nations'),
#  ('that', 'the'),
#  ('that', 'row'),
#  ('the', 'nations'),
#  ('the', 'that'),
#  ('the', 'row'),
#  ('the', 'could'),
#  ('row', 'that'),
#  ('row', 'the'),
#  ('row', 'could'),
#  ('row', 'inflict'),
#  ('could', 'the'),
#  ('could', 'row'),
#  ('could', 'inflict'),
#  ('could', 'far'),
#  ('inflict', 'row'),
#  ('inflict', 'could'),
#  ('inflict', 'far'),
#  ('inflict', '-'),
#  ('far', 'could'),
#  ('far', 'inflict'),
#  ('far', '-'),
#  ('far', 'reaching'),
#  ('-', 'inflict'),
#  ('-', 'far'),
#  ('-', 'reaching'),
#  ('-', 'economic'),
#  ('reaching', 'far'),
#  ('reaching', '-'),
#  ('reaching', 'economic'),
#  ('reaching', 'damage'),
#  ('economic', '-'),
#  ('economic', 'reaching'),
#  ('economic', 'damage'),
#  ('economic', ','),
#  ('damage', 'reaching'),
#  ('damage', 'economic'),
#  ('damage', ','),
#  ('damage', 'businessmen'),
#  (',', 'economic'),
#  (',', 'damage'),
#  (',', 'businessmen'),
#  (',', 'and'),
#  ('businessmen', 'damage'),
#  ('businessmen', ','),
#  ('businessmen', 'and'),
#  ('businessmen', 'officials'),
#  ('and', ','),
#  ('and', 'businessmen'),
#  ('and', 'officials'),
#  ('and', 'said'),
#  ('officials', 'businessmen'),
#  ('officials', 'and'),
#  ('officials', 'said'),
#  ('officials', '.'),
#  ('Reuter', 'They'),
#  ('Reuter', 'told'),
#  ('Reuter', 'correspondents'),
#  ('Reuter', 'in'),
#  ('correspondents', 'told'),
#  ('correspondents', 'Reuter'),
#  ('correspondents', 'in'),
#  ('correspondents', 'Asian'),
#  ('in', 'Reuter'),
#  ('in', 'correspondents'),
#  ('in', 'Asian'),
#  ('in', 'capitals'),
#  ('Asian', 'correspondents'),
#  ('Asian', 'in'),
#  ('Asian', 'capitals'),
#  ('Asian', 'a'),
#  ('capitals', 'in'),
#  ('capitals', 'Asian'),
#  ('capitals', 'a'),
#  ('capitals', 'U'),
#  ('a', 'Asian'),
#  ('a', 'capitals'),
#  ('a', 'U'),
#  ('a', '.'),
#  ('U', 'capitals'),
#  ('U', 'a'),
#  ('U', '.'),
#  ('U', 'S'),
#  ('.', 'a'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.'),
#  ('S', 'Move'),
#  ('.', '.'),
#  ('.', 'S'),
#  ('.', 'Move'),
#  ('.', 'against'),
#  ('Move', 'S'),
#  ('Move', '.'),
#  ('Move', 'against'),
#  ('Move', 'Japan'),
#  ('against', '.'),
#  ('against', 'Move'),
#  ('against', 'Japan'),
#  ('against', 'might'),
#  ('Japan', 'Move'),
#  ('Japan', 'against'),
#  ('Japan', 'might'),
#  ('Japan', 'boost'),
#  ('might', 'against'),
#  ('might', 'Japan'),
#  ('might', 'boost'),
#  ('might', 'protectionist'),
#  ('boost', 'Japan'),
#  ('boost', 'might'),
#  ('boost', 'protectionist'),
#  ('boost', 'sentiment'),
#  ('protectionist', 'might'),
#  ('protectionist', 'boost'),
#  ('protectionist', 'sentiment'),
#  ('protectionist', 'in'),
#  ('sentiment', 'boost'),
#  ('sentiment', 'protectionist'),
#  ('sentiment', 'in'),
#  ('sentiment', 'the'),
#  ('in', 'protectionist'),
#  ('in', 'sentiment'),
#  ('in', 'the'),
#  ('in', 'U'),
#  ('the', 'sentiment'),
#  ('the', 'in'),
#  ('the', 'U'),
#  ('the', '.'),
#  ('U', 'in'),
#  ('U', 'the'),
#  ('U', '.'),
#  ('U', 'S'),
#  ('.', 'the'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.'),
#  ('S', 'And'),
#  ('.', '.'),
#  ('.', 'S'),
#  ('.', 'And'),
#  ('.', 'lead'),
#  ('And', 'S'),
#  ('And', '.'),
#  ('And', 'lead'),
#  ('And', 'to'),
#  ('lead', '.'),
#  ('lead', 'And'),
#  ('lead', 'to'),
#  ('lead', 'curbs'),
#  ('to', 'And'),
#  ('to', 'lead'),
#  ('to', 'curbs'),
#  ('to', 'on'),
#  ('curbs', 'lead'),
#  ('curbs', 'to'),
#  ('curbs', 'on'),
#  ('curbs', 'American'),
#  ('on', 'to'),
#  ('on', 'curbs'),
#  ('on', 'American'),
#  ('on', 'imports'),
#  ('American', 'curbs'),
#  ('American', 'on'),
#  ('American', 'imports'),
#  ('American', 'of'),
#  ('imports', 'on'),
#  ('imports', 'American'),
#  ('imports', 'of'),
#  ('imports', 'their'),
#  ('of', 'American'),
#  ('of', 'imports'),
#  ('of', 'their'),
#  ('of', 'products'),
#  ('their', 'imports'),
#  ('their', 'of'),
#  ('their', 'products'),
#  ('their', '.'),
#  ('exporters', 'But'),
#  ('exporters', 'some'),
#  ('exporters', 'said'),
#  ('exporters', 'that'),
#  ('said', 'some'),
#  ('said', 'exporters'),
#  ('said', 'that'),
#  ('said', 'while'),
#  ('that', 'exporters'),
#  ('that', 'said'),
#  ('that', 'while'),
#  ('that', 'the'),
#  ('while', 'said'),
#  ('while', 'that'),
#  ('while', 'the'),
#  ('while', 'conflict'),
#  ('the', 'that'),
#  ('the', 'while'),
#  ('the', 'conflict'),
#  ('the', 'would'),
#  ('conflict', 'while'),
#  ('conflict', 'the'),
#  ('conflict', 'would'),
#  ('conflict', 'hurt'),
#  ('would', 'the'),
#  ('would', 'conflict'),
#  ('would', 'hurt'),
#  ('would', 'them'),
#  ('hurt', 'conflict'),
#  ('hurt', 'would'),
#  ('hurt', 'them'),
#  ('hurt', 'in'),
#  ('them', 'would'),
#  ('them', 'hurt'),
#  ('them', 'in'),
#  ('them', 'the'),
#  ('in', 'hurt'),
#  ('in', 'them'),
#  ('in', 'the'),
#  ('in', 'long'),
#  ('the', 'them'),
#  ('the', 'in'),
#  ('the', 'long'),
#  ('the', '-'),
#  ('long', 'in'),
#  ('long', 'the'),
#  ('long', '-'),
#  ('long', 'run'),
#  ('-', 'the'),
#  ('-', 'long'),
#  ('-', 'run'),
#  ('-', ','),
#  ('run', 'long'),
#  ('run', '-'),
#  ('run', ','),
#  ('run', 'in'),
#  (',', '-'),
#  (',', 'run'),
#  (',', 'in'),
#  (',', 'the'),
#  ('in', 'run'),
#  ('in', ','),
#  ('in', 'the'),
#  ('in', 'short'),
#  ('the', ','),
#  ('the', 'in'),
#  ('the', 'short'),
#  ('the', '-'),
#  ('short', 'in'),
#  ('short', 'the'),
#  ('short', '-'),
#  ('short', 'term'),
#  ('-', 'the'),
#  ('-', 'short'),
#  ('-', 'term'),
#  ('-', 'Tokyo'),
#  ('term', 'short'),
#  ('term', '-'),
#  ('term', 'Tokyo'),
#  ('term', "'"),
#  ('Tokyo', '-'),
#  ('Tokyo', 'term'),
#  ('Tokyo', "'"),
#  ('Tokyo', 's'),
#  ("'", 'term'),
#  ("'", 'Tokyo'),
#  ("'", 's'),
#  ("'", 'loss'),
#  ('s', 'Tokyo'),
#  ('s', "'"),
#  ('s', 'loss'),
#  ('s', 'might'),
#  ('loss', "'"),
#  ('loss', 's'),
#  ('loss', 'might'),
#  ('loss', 'be'),
#  ('might', 's'),
#  ('might', 'loss'),
#  ('might', 'be'),
#  ('might', 'their'),
#  ('be', 'loss'),
#  ('be', 'might'),
#  ('be', 'their'),
#  ('be', 'gain'),
#  ('their', 'might'),
#  ('their', 'be'),
#  ('their', 'gain'),
#  ('their', '.'),
#  ('.', 'The'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.'),
#  ('S', 'Has'),
#  ('.', '.'),
#  ('.', 'S'),
#  ('.', 'Has'),
#  ('.', 'said'),
#  ('Has', 'S'),
#  ('Has', '.'),
#  ('Has', 'said'),
#  ('Has', 'it'),
#  ('said', '.'),
#  ('said', 'Has'),
#  ('said', 'it'),
#  ('said', 'will'),
#  ('it', 'Has'),
#  ('it', 'said'),
#  ('it', 'will'),
#  ('it', 'impose'),
#  ('will', 'said'),
#  ('will', 'it'),
#  ('will', 'impose'),
#  ('will', '300'),
#  ('impose', 'it'),
#  ('impose', 'will'),
#  ('impose', '300'),
#  ('impose', 'mln'),
#  ('300', 'will'),
#  ('300', 'impose'),
#  ('300', 'mln'),
#  ('300', 'dlrs'),
#  ('mln', 'impose'),
#  ('mln', '300'),
#  ('mln', 'dlrs'),
#  ('mln', 'of'),
#  ('dlrs', '300'),
#  ('dlrs', 'mln'),
#  ('dlrs', 'of'),
#  ('dlrs', 'tariffs'),
#  ('of', 'mln'),
#  ('of', 'dlrs'),
#  ('of', 'tariffs'),
#  ('of', 'on'),
#  ('tariffs', 'dlrs'),
#  ('tariffs', 'of'),
#  ('tariffs', 'on'),
#  ('tariffs', 'imports'),
#  ('on', 'of'),
#  ('on', 'tariffs'),
#  ('on', 'imports'),
#  ('on', 'of'),
#  ('imports', 'tariffs'),
#  ('imports', 'on'),
#  ('imports', 'of'),
#  ('imports', 'Japanese'),
#  ('of', 'on'),
#  ('of', 'imports'),
#  ('of', 'Japanese'),
#  ('of', 'electronics'),
#  ('Japanese', 'imports'),
#  ('Japanese', 'of'),
#  ('Japanese', 'electronics'),
#  ('Japanese', 'goods'),
#  ('electronics', 'of'),
#  ('electronics', 'Japanese'),
#  ('electronics', 'goods'),
#  ('electronics', 'on'),
#  ('goods', 'Japanese'),
#  ('goods', 'electronics'),
#  ('goods', 'on'),
#  ('goods', 'April'),
#  ('on', 'electronics'),
#  ('on', 'goods'),
#  ('on', 'April'),
#  ('on', '17'),
#  ('April', 'goods'),
#  ('April', 'on'),
#  ('April', '17'),
#  ('April', ','),
#  ('17', 'on'),
#  ('17', 'April'),
#  ('17', ','),
#  ('17', 'in'),
#  (',', 'April'),
#  (',', '17'),
#  (',', 'in'),
#  (',', 'retaliation'),
#  ('in', '17'),
#  ('in', ','),
#  ('in', 'retaliation'),
#  ('in', 'for'),
#  ('retaliation', ','),
#  ('retaliation', 'in'),
#  ('retaliation', 'for'),
#  ('retaliation', 'Japan'),
#  ('for', 'in'),
#  ('for', 'retaliation'),
#  ('for', 'Japan'),
#  ('for', "'"),
#  ('Japan', 'retaliation'),
#  ('Japan', 'for'),
#  ('Japan', "'"),
#  ('Japan', 's'),
#  ("'", 'for'),
#  ("'", 'Japan'),
#  ("'", 's'),
#  ("'", 'alleged'),
#  ('s', 'Japan'),
#  ('s', "'"),
#  ('s', 'alleged'),
#  ('s', 'failure'),
#  ('alleged', "'"),
#  ('alleged', 's'),
#  ('alleged', 'failure'),
#  ('alleged', 'to'),
#  ('failure', 's'),
#  ('failure', 'alleged'),
#  ('failure', 'to'),
#  ('failure', 'stick'),
#  ('to', 'alleged'),
#  ('to', 'failure'),
#  ('to', 'stick'),
#  ('to', 'to'),
#  ('stick', 'failure'),
#  ('stick', 'to'),
#  ('stick', 'to'),
#  ('stick', 'a'),
#  ('to', 'to'),
#  ('to', 'stick'),
#  ('to', 'a'),
#  ('to', 'pact'),
#  ('a', 'stick'),
#  ('a', 'to'),
#  ('a', 'pact'),
#  ('a', 'not'),
#  ('pact', 'to'),
#  ('pact', 'a'),
#  ('pact', 'not'),
#  ('pact', 'to'),
#  ('not', 'a'),
#  ('not', 'pact'),
#  ('not', 'to'),
#  ('not', 'sell'),
#  ('to', 'pact'),
#  ('to', 'not'),
#  ('to', 'sell'),
#  ('to', 'semiconductors'),
#  ('sell', 'not'),
#  ('sell', 'to'),
#  ('sell', 'semiconductors'),
#  ('sell', 'on'),
#  ('semiconductors', 'to'),
#  ('semiconductors', 'sell'),
#  ('semiconductors', 'on'),
#  ('semiconductors', 'world'),
#  ('on', 'sell'),
#  ('on', 'semiconductors'),
#  ('on', 'world'),
#  ('on', 'markets'),
#  ('world', 'semiconductors'),
#  ('world', 'on'),
#  ('world', 'markets'),
#  ('world', 'at'),
#  ('markets', 'on'),
#  ('markets', 'world'),
#  ('markets', 'at'),
#  ('markets', 'below'),
#  ('at', 'world'),
#  ('at', 'markets'),
#  ('at', 'below'),
#  ('at', 'cost'),
#  ('below', 'markets'),
#  ('below', 'at'),
#  ('below', 'cost'),
#  ('below', '.'),
#  ('estimates', 'Unofficial'),
#  ('estimates', 'Japanese'),
#  ('estimates', 'put'),
#  ('estimates', 'the'),
#  ('put', 'Japanese'),
#  ('put', 'estimates'),
#  ('put', 'the'),
#  ('put', 'impact'),
#  ('the', 'estimates'),
#  ('the', 'put'),
#  ('the', 'impact'),
#  ('the', 'of'),
#  ('impact', 'put'),
#  ('impact', 'the'),
#  ('impact', 'of'),
#  ('impact', 'the'),
#  ('of', 'the'),
#  ('of', 'impact'),
#  ('of', 'the'),
#  ('of', 'tariffs'),
#  ('the', 'impact'),
#  ('the', 'of'),
#  ('the', 'tariffs'),
#  ('the', 'at'),
#  ('tariffs', 'of'),
#  ('tariffs', 'the'),
#  ('tariffs', 'at'),
#  ('tariffs', '10'),
#  ('at', 'the'),
#  ('at', 'tariffs'),
#  ('at', '10'),
#  ('at', 'billion'),
#  ('10', 'tariffs'),
#  ('10', 'at'),
#  ('10', 'billion'),
#  ('10', 'dlrs'),
#  ('billion', 'at'),
#  ('billion', '10'),
#  ('billion', 'dlrs'),
#  ('billion', 'and'),
#  ('dlrs', '10'),
#  ('dlrs', 'billion'),
#  ('dlrs', 'and'),
#  ('dlrs', 'spokesmen'),
#  ('and', 'billion'),
#  ('and', 'dlrs'),
#  ('and', 'spokesmen'),
#  ('and', 'for'),
#  ('spokesmen', 'dlrs'),
#  ('spokesmen', 'and'),
#  ('spokesmen', 'for'),
#  ('spokesmen', 'major'),
#  ('for', 'and'),
#  ('for', 'spokesmen'),
#  ('for', 'major'),
#  ('for', 'electronics'),
#  ('major', 'spokesmen'),
#  ('major', 'for'),
#  ('major', 'electronics'),
#  ('major', 'firms'),
#  ('electronics', 'for'),
#  ('electronics', 'major'),
#  ('electronics', 'firms'),
#  ('electronics', 'said'),
#  ('firms', 'major'),
#  ('firms', 'electronics'),
#  ('firms', 'said'),
#  ('firms', 'they'),
#  ('said', 'electronics'),
#  ('said', 'firms'),
#  ('said', 'they'),
#  ('said', 'would'),
#  ('they', 'firms'),
#  ('they', 'said'),
#  ('they', 'would'),
#  ('they', 'virtually'),
#  ('would', 'said'),
#  ('would', 'they'),
#  ('would', 'virtually'),
#  ('would', 'halt'),
#  ('virtually', 'they'),
#  ('virtually', 'would'),
#  ('virtually', 'halt'),
#  ('virtually', 'exports'),
#  ('halt', 'would'),
#  ('halt', 'virtually'),
#  ('halt', 'exports'),
#  ('halt', 'of'),
#  ('exports', 'virtually'),
#  ('exports', 'halt'),
#  ('exports', 'of'),
#  ('exports', 'products'),
#  ('of', 'halt'),
#  ('of', 'exports'),
#  ('of', 'products'),
#  ('of', 'hit'),
#  ('products', 'exports'),
#  ('products', 'of'),
#  ('products', 'hit'),
#  ('products', 'by'),
#  ('hit', 'of'),
#  ('hit', 'products'),
#  ('hit', 'by'),
#  ('hit', 'the'),
#  ('by', 'products'),
#  ('by', 'hit'),
#  ('by', 'the'),
#  ('by', 'new'),
#  ('the', 'hit'),
#  ('the', 'by'),
#  ('the', 'new'),
#  ('the', 'taxes'),
#  ('new', 'by'),
#  ('new', 'the'),
#  ('new', 'taxes'),
#  ('new', '.'),
#  ('wouldn', '"'),
#  ('wouldn', 'We'),
#  ('wouldn', "'"),
#  ('wouldn', 't'),
#  ("'", 'We'),
#  ("'", 'wouldn'),
#  ("'", 't'),
#  ("'", 'be'),
#  ('t', 'wouldn'),
#  ('t', "'"),
#  ('t', 'be'),
#  ('t', 'able'),
#  ('be', "'"),
#  ('be', 't'),
#  ('be', 'able'),
#  ('be', 'to'),
#  ('able', 't'),
#  ('able', 'be'),
#  ('able', 'to'),
#  ('able', 'do'),
#  ('to', 'be'),
#  ('to', 'able'),
#  ('to', 'do'),
#  ('to', 'business'),
#  ('do', 'able'),
#  ('do', 'to'),
#  ('do', 'business'),
#  ('do', ',"'),
#  ('business', 'to'),
#  ('business', 'do'),
#  ('business', ',"'),
#  ('business', 'said'),
#  (',"', 'do'),
#  (',"', 'business'),
#  (',"', 'said'),
#  (',"', 'a'),
#  ('said', 'business'),
#  ('said', ',"'),
#  ('said', 'a'),
#  ('said', 'spokesman'),
#  ('a', ',"'),
#  ('a', 'said'),
#  ('a', 'spokesman'),
#  ('a', 'for'),
#  ('spokesman', 'said'),
#  ('spokesman', 'a'),
#  ('spokesman', 'for'),
#  ('spokesman', 'leading'),
#  ('for', 'a'),
#  ('for', 'spokesman'),
#  ('for', 'leading'),
#  ('for', 'Japanese'),
#  ('leading', 'spokesman'),
#  ('leading', 'for'),
#  ('leading', 'Japanese'),
#  ('leading', 'electronics'),
#  ('Japanese', 'for'),
#  ('Japanese', 'leading'),
#  ('Japanese', 'electronics'),
#  ('Japanese', 'firm'),
#  ('electronics', 'leading'),
#  ('electronics', 'Japanese'),
#  ('electronics', 'firm'),
#  ('electronics', 'Matsushita'),
#  ('firm', 'Japanese'),
#  ('firm', 'electronics'),
#  ('firm', 'Matsushita'),
#  ('firm', 'Electric'),
#  ('Matsushita', 'electronics'),
#  ('Matsushita', 'firm'),
#  ('Matsushita', 'Electric'),
#  ('Matsushita', 'Industrial'),
#  ('Electric', 'firm'),
#  ('Electric', 'Matsushita'),
#  ('Electric', 'Industrial'),
#  ('Electric', 'Co'),
#  ('Industrial', 'Matsushita'),
#  ('Industrial', 'Electric'),
#  ('Industrial', 'Co'),
#  ('Industrial', 'Ltd'),
#  ('Co', 'Electric'),
#  ('Co', 'Industrial'),
#  ('Co', 'Ltd'),
#  ('Co', '&'),
#  ('Ltd', 'Industrial'),
#  ('Ltd', 'Co'),
#  ('Ltd', '&'),
#  ('Ltd', 'lt'),
#  ('&', 'Co'),
#  ('&', 'Ltd'),
#  ('&', 'lt'),
#  ('&', ';'),
#  ('lt', 'Ltd'),
#  ('lt', '&'),
#  ('lt', ';'),
#  ('lt', 'MC'),
#  (';', '&'),
#  (';', 'lt'),
#  (';', 'MC'),
#  (';', '.'),
#  ('MC', 'lt'),
#  ('MC', ';'),
#  ('MC', '.'),
#  ('MC', 'T'),
#  ('.', ';'),
#  ('.', 'MC'),
#  ('.', 'T'),
#  ('.', '>.'),
#  ('the', '"'),
#  ('the', 'If'),
#  ('the', 'tariffs'),
#  ('the', 'remain'),
#  ('tariffs', 'If'),
#  ('tariffs', 'the'),
#  ('tariffs', 'remain'),
#  ('tariffs', 'in'),
#  ('remain', 'the'),
#  ('remain', 'tariffs'),
#  ('remain', 'in'),
#  ('remain', 'place'),
#  ('in', 'tariffs'),
#  ('in', 'remain'),
#  ('in', 'place'),
#  ('in', 'for'),
#  ('place', 'remain'),
#  ('place', 'in'),
#  ('place', 'for'),
#  ('place', 'any'),
#  ('for', 'in'),
#  ('for', 'place'),
#  ('for', 'any'),
#  ('for', 'length'),
#  ('any', 'place'),
#  ('any', 'for'),
#  ('any', 'length'),
#  ('any', 'of'),
#  ('length', 'for'),
#  ('length', 'any'),
#  ('length', 'of'),
#  ('length', 'time'),
#  ('of', 'any'),
#  ('of', 'length'),
#  ('of', 'time'),
#  ('of', 'beyond'),
#  ('time', 'length'),
#  ('time', 'of'),
#  ('time', 'beyond'),
#  ('time', 'a'),
#  ('beyond', 'of'),
#  ('beyond', 'time'),
#  ('beyond', 'a'),
#  ('beyond', 'few'),
#  ('a', 'time'),
#  ('a', 'beyond'),
#  ('a', 'few'),
#  ('a', 'months'),
#  ('few', 'beyond'),
#  ('few', 'a'),
#  ('few', 'months'),
#  ('few', 'it'),
#  ('months', 'a'),
#  ('months', 'few'),
#  ('months', 'it'),
#  ('months', 'will'),
#  ('it', 'few'),
#  ('it', 'months'),
#  ('it', 'will'),
#  ('it', 'mean'),
#  ('will', 'months'),
#  ('will', 'it'),
#  ('will', 'mean'),
#  ('will', 'the'),
#  ('mean', 'it'),
#  ('mean', 'will'),
#  ('mean', 'the'),
#  ('mean', 'complete'),
#  ('the', 'will'),
#  ('the', 'mean'),
#  ('the', 'complete'),
#  ('the', 'erosion'),
#  ('complete', 'mean'),
#  ('complete', 'the'),
#  ('complete', 'erosion'),
#  ('complete', 'of'),
#  ('erosion', 'the'),
#  ('erosion', 'complete'),
#  ('erosion', 'of'),
#  ('erosion', 'exports'),
#  ('of', 'complete'),
#  ('of', 'erosion'),
#  ('of', 'exports'),
#  ('of', '('),
#  ('exports', 'erosion'),
#  ('exports', 'of'),
#  ('exports', '('),
#  ('exports', 'of'),
#  ('(', 'of'),
#  ('(', 'exports'),
#  ('(', 'of'),
#  ('(', 'goods'),
#  ('of', 'exports'),
#  ('of', '('),
#  ('of', 'goods'),
#  ('of', 'subject'),
#  ('goods', '('),
#  ('goods', 'of'),
#  ('goods', 'subject'),
#  ('goods', 'to'),
#  ('subject', 'of'),
#  ('subject', 'goods'),
#  ('subject', 'to'),
#  ('subject', 'tariffs'),
#  ('to', 'goods'),
#  ('to', 'subject'),
#  ('to', 'tariffs'),
#  ('to', ')'),
#  ('tariffs', 'subject'),
#  ('tariffs', 'to'),
#  ('tariffs', ')'),
#  ('tariffs', 'to'),
#  (')', 'to'),
#  (')', 'tariffs'),
#  (')', 'to'),
#  (')', 'the'),
#  ('to', 'tariffs'),
#  ('to', ')'),
#  ('to', 'the'),
#  ('to', 'U'),
#  ('the', ')'),
#  ('the', 'to'),
#  ('the', 'U'),
#  ('the', '.'),
#  ('U', 'to'),
#  ('U', 'the'),
#  ('U', '.'),
#  ('U', 'S'),
#  ('.', 'the'),
#  ('.', 'U'),
#  ('.', 'S'),
#  ('.', '.,"'),
#  ('S', 'U'),
#  ('S', '.'),
#  ('S', '.,"'),
#  ('S', 'said'),
#  ('.,"', '.'),
#  ('.,"', 'S'),
#  ('.,"', 'said'),
#  ('.,"', 'Tom'),
#  ('said', 'S'),
#  ('said', '.,"'),
#  ('said', 'Tom'),
#  ('said', 'Murtha'),
#  ('Tom', '.,"'),
#  ('Tom', 'said'),
#  ('Tom', 'Murtha'),
#  ('Tom', ','),
#  ('Murtha', 'said'),
#  ('Murtha', 'Tom'),
#  ('Murtha', ','),
#  ('Murtha', 'a'),
#  (',', 'Tom'),
#  (',', 'Murtha'),
#  (',', 'a'),
#  (',', 'stock'),
#  ('a', 'Murtha'),
#  ('a', ','),
#  ('a', 'stock'),
#  ('a', 'analyst'),
#  ('stock', ','),
#  ('stock', 'a'),
#  ('stock', 'analyst'),
#  ('stock', 'at'),
#  ('analyst', 'a'),
#  ('analyst', 'stock'),
#  ('analyst', 'at'),
#  ('analyst', 'the'),
#  ('at', 'stock'),
#  ('at', 'analyst'),
#  ('at', 'the'),
#  ('at', 'Tokyo'),
#  ('the', 'analyst'),
#  ('the', 'at'),
#  ('the', 'Tokyo'),
#  ('the', 'office'),
#  ('Tokyo', 'at'),
#  ('Tokyo', 'the'),
#  ('Tokyo', 'office'),
#  ('Tokyo', 'of'),
#  ...]

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('FEAR', 'ASIAN'): 1,
#          ('FEAR', 'EXPORTERS'): 1,
#          ('FEAR', 'DAMAGE'): 1,
#          ('FEAR', 'FROM'): 1,
#          ('DAMAGE', 'EXPORTERS'): 1,
#          ('DAMAGE', 'FEAR'): 1,
#          ('DAMAGE', 'FROM'): 1,
#          ('DAMAGE', 'U'): 1,
#          ('FROM', 'FEAR'): 1,
#          ('FROM', 'DAMAGE'): 1,
#          ('FROM', 'U'): 1,
#          ('FROM', '.'): 5,
#          ('U', 'DAMAGE'): 1,
#          ('U', 'FROM'): 1,
#          ('U', '.'): 940,
#          ('U', 'S'): 877,
#          ('.', 'FROM'): 5,
#          ('.', 'U'): 979,
#          ('.', 'S'): 1807,
#          ('.', '.-'): 38,
#          ('S', 'U'): 911,
#          ('S', '.'): 1801,
#          ('S', '.-'): 17,
#          ('S', 'JAPAN'): 4,
#          ('.-', '.'): 41,
#          ('.-', 'S'): 17,
#          ('.-', 'JAPAN'): 1,
#          ('.-', 'RIFT'): 1,
#          ('JAPAN', 'S'): 1,
#          ('JAPAN', '.-'): 1,
#          ('JAPAN', 'RIFT'): 1,
#          ('JAPAN', 'Mounting'): 1,
#          ('RIFT', '.-'): 1,
#          ('RIFT', 'JAPAN'): 1,
#          ('RIFT', 'Mounting'): 1,
#          ('RIFT', 'trade'): 1,
#          ('Mounting', 'JAPAN'): 1,
#          ('Mounting', 'RIFT'): 1,
#          ('Mounting', 'trade'): 1,
#          ('Mounting', 'friction'): 1,
#          ('trade', 'RIFT'): 1,
#          ('trade', 'Mounting'): 1,
#          ('trade', 'friction'): 7,
#          ('trade', 'between'): 17,
#          ('friction', 'Mounting'): 1,
#          ('friction', 'trade'): 6,
#          ('friction', 'between'): 3,
#          ('friction', 'the'): 3,
#          ('between', 'trade'): 17,
#          ('between', 'friction'): 3,
#          ('between', 'the'): 61,
#          ('between', 'U'): 5,
#          ('the', 'friction'): 3,
#          ('the', 'between'): 60,
#          ('the', 'U'): 366,
#          ('the', '.'): 814,
#          ('U', 'between'): 5,
#          ('U', 'the'): 370,
#          ('.', 'the'): 398,
#          ('.', '.'): 2164,
#          ('S', 'And'): 29,
#          ('.', 'And'): 32,
#          ('.', 'Japan'): 15,
#          ('And', 'S'): 29,
#          ('And', '.'): 34,
#          ('And', 'Japan'): 6,
#          ('And', 'has'): 2,
#          ('Japan', '.'): 17,
#          ('Japan', 'And'): 6,
#          ('Japan', 'has'): 14,
#          ('Japan', 'raised'): 1,
#          ('has', 'And'): 2,
#          ('has', 'Japan'): 16,
#          ('has', 'raised'): 6,
#          ('has', 'fears'): 1,
#          ('raised', 'Japan'): 1,
#          ('raised', 'has'): 7,
#          ('raised', 'fears'): 1,
#          ('raised', 'among'): 1,
#          ('fears', 'has'): 1,
#          ('fears', 'raised'): 1,
#          ('fears', 'among'): 1,
#          ('fears', 'many'): 1,
#          ('among', 'raised'): 1,
#          ('among', 'fears'): 1,
#          ('among', 'many'): 1,
#          ('among', 'of'): 1,
#          ('many', 'fears'): 1,
#          ('many', 'among'): 1,
#          ('many', 'of'): 5,
#          ('many', 'Asia'): 1,
#          ('of', 'among'): 1,
#          ('of', 'many'): 6,
#          ('of', 'Asia'): 1,
#          ('of', "'"): 156,
#          ('Asia', 'many'): 1,
#          ('Asia', 'of'): 1,
#          ('Asia', "'"): 1,
#          ('Asia', 's'): 1,
#          ("'", 'of'): 160,
#          ("'", 'Asia'): 1,
#          ("'", 's'): 1593,
#          ("'", 'exporting'): 1,
#          ('s', 'Asia'): 1,
#          ('s', "'"): 1707,
#          ('s', 'exporting'): 1,
#          ('s', 'nations'): 2,
#          ('exporting', "'"): 1,
#          ('exporting', 's'): 1,
#          ('exporting', 'nations'): 2,
#          ('exporting', 'that'): 1,
#          ('nations', 's'): 2,
#          ('nations', 'exporting'): 2,
#          ('nations', 'that'): 4,
#          ('nations', 'the'): 16,
#          ('that', 'exporting'): 1,
#          ('that', 'nations'): 4,
#          ('that', 'the'): 386,
#          ('that', 'row'): 1,
#          ('the', 'nations'): 19,
#          ('the', 'that'): 385,
#          ('the', 'row'): 1,
#          ('the', 'could'): 47,
#          ('row', 'that'): 1,
#          ('row', 'the'): 1,
#          ('row', 'could'): 1,
#          ('row', 'inflict'): 1,
#          ('could', 'the'): 49,
#          ('could', 'row'): 1,
#          ('could', 'inflict'): 1,
#          ('could', 'far'): 1,
#          ('inflict', 'row'): 1,
#          ('inflict', 'could'): 1,
#          ('inflict', 'far'): 1,
#          ('inflict', '-'): 1,
#          ('far', 'could'): 1,
#          ('far', 'inflict'): 1,
#          ('far', '-'): 1,
#          ('far', 'reaching'): 1,
#          ('-', 'inflict'): 1,
#          ('-', 'far'): 1,
#          ('-', 'reaching'): 1,
#          ('-', 'economic'): 11,
#          ('reaching', 'far'): 1,
#          ('reaching', '-'): 1,
#          ('reaching', 'economic'): 1,
#          ('reaching', 'damage'): 1,
#          ('economic', '-'): 11,
#          ('economic', 'reaching'): 1,
#          ('economic', 'damage'): 1,
#          ('economic', ','): 32,
#          ('damage', 'reaching'): 1,
#          ('damage', 'economic'): 1,
#          ('damage', ','): 4,
#          ('damage', 'businessmen'): 1,
#          (',', 'economic'): 32,
#          (',', 'damage'): 4,
#          (',', 'businessmen'): 2,
#          (',', 'and'): 871,
#          ('businessmen', 'damage'): 1,
#          ('businessmen', ','): 2,
#          ('businessmen', 'and'): 5,
#          ('businessmen', 'officials'): 2,
#          ('and', ','): 871,
#          ('and', 'businessmen'): 4,
#          ('and', 'officials'): 12,
#          ('and', 'said'): 74,
#          ('officials', 'businessmen'): 2,
#          ('officials', 'and'): 11,
#          ('officials', 'said'): 59,
#          ('officials', '.'): 48,
#          ('Reuter', 'They'): 1,
#          ('Reuter', 'told'): 1,
#          ('Reuter', 'correspondents'): 3,
#          ('Reuter', 'in'): 1,
#          ('correspondents', 'told'): 1,
#          ('correspondents', 'Reuter'): 3,
#          ('correspondents', 'in'): 1,
#          ('correspondents', 'Asian'): 1,
#          ('in', 'Reuter'): 1,
#          ('in', 'correspondents'): 1,
#          ('in', 'Asian'): 2,
#          ('in', 'capitals'): 1,
#          ('Asian', 'correspondents'): 1,
#          ('Asian', 'in'): 2,
#          ('Asian', 'capitals'): 1,
#          ('Asian', 'a'): 1,
#          ('capitals', 'in'): 1,
#          ('capitals', 'Asian'): 1,
#          ('capitals', 'a'): 1,
#          ('capitals', 'U'): 1,
#          ('a', 'Asian'): 1,
#          ('a', 'capitals'): 1,
#          ('a', 'U'): 29,
#          ('a', '.'): 277,
#          ('U', 'capitals'): 1,
#          ('U', 'a'): 29,
#          ('.', 'a'): 135,
#          ('S', 'Move'): 1,
#          ('.', 'Move'): 1,
#          ('.', 'against'): 52,
#          ('Move', 'S'): 1,
#          ('Move', '.'): 1,
#          ('Move', 'against'): 1,
#          ('Move', 'Japan'): 1,
#          ('against', '.'): 53,
#          ('against', 'Move'): 1,
#          ('against', 'Japan'): 7,
#          ('against', 'might'): 2,
#          ('Japan', 'Move'): 1,
#          ('Japan', 'against'): 10,
#          ('Japan', 'might'): 5,
#          ('Japan', 'boost'): 1,
#          ('might', 'against'): 2,
#          ('might', 'Japan'): 5,
#          ('might', 'boost'): 2,
#          ('might', 'protectionist'): 1,
#          ('boost', 'Japan'): 1,
#          ('boost', 'might'): 2,
#          ('boost', 'protectionist'): 1,
#          ('boost', 'sentiment'): 1,
#          ('protectionist', 'might'): 1,
#          ('protectionist', 'boost'): 1,
#          ('protectionist', 'sentiment'): 1,
#          ('protectionist', 'in'): 6,
#          ('sentiment', 'boost'): 1,
#          ('sentiment', 'protectionist'): 1,
#          ('sentiment', 'in'): 1,
#          ('sentiment', 'the'): 6,
#          ('in', 'protectionist'): 6,
#          ('in', 'sentiment'): 1,
#          ('in', 'the'): 1286,
#          ('in', 'U'): 80,
#          ('the', 'sentiment'): 6,
#          ('the', 'in'): 1307,
#          ('U', 'in'): 82,
#          ('.', 'lead'): 2,
#          ('And', 'lead'): 1,
#          ('And', 'to'): 1,
#          ('lead', '.'): 4,
#          ('lead', 'And'): 1,
#          ('lead', 'to'): 34,
#          ('lead', 'curbs'): 1,
#          ('to', 'And'): 2,
#          ('to', 'lead'): 34,
#          ('to', 'curbs'): 1,
#          ('to', 'on'): 73,
#          ('curbs', 'lead'): 1,
#          ('curbs', 'to'): 1,
#          ('curbs', 'on'): 6,
#          ('curbs', 'American'): 1,
#          ('on', 'to'): 73,
#          ('on', 'curbs'): 6,
#          ('on', 'American'): 9,
#          ('on', 'imports'): 19,
#          ('American', 'curbs'): 1,
#          ('American', 'on'): 9,
#          ('American', 'imports'): 1,
#          ('American', 'of'): 20,
#          ('imports', 'on'): 19,
#          ('imports', 'American'): 1,
#          ('imports', 'of'): 33,
#          ('imports', 'their'): 1,
#          ('of', 'American'): 20,
#          ('of', 'imports'): 37,
#          ('of', 'their'): 33,
#          ('of', 'products'): 33,
#          ('their', 'imports'): 1,
#          ('their', 'of'): 33,
#          ('their', 'products'): 3,
#          ('their', '.'): 23,
#          ('exporters', 'But'): 1,
#          ('exporters', 'some'): 1,
#          ('exporters', 'said'): 2,
#          ('exporters', 'that'): 2,
#          ('said', 'some'): 11,
#          ('said', 'exporters'): 2,
#          ('said', 'that'): 116,
#          ('said', 'while'): 6,
#          ('that', 'exporters'): 2,
#          ('that', 'said'): 153,
#          ('that', 'while'): 16,
#          ('while', 'said'): 10,
#          ('while', 'that'): 16,
#          ('while', 'the'): 39,
#          ('while', 'conflict'): 1,
#          ('the', 'while'): 40,
#          ('the', 'conflict'): 1,
#          ('the', 'would'): 181,
#          ('conflict', 'while'): 1,
#          ('conflict', 'the'): 1,
#          ('conflict', 'would'): 1,
#          ('conflict', 'hurt'): 1,
#          ('would', 'the'): 182,
#          ('would', 'conflict'): 1,
#          ('would', 'hurt'): 2,
#          ('would', 'them'): 2,
#          ('hurt', 'conflict'): 1,
#          ('hurt', 'would'): 2,
#          ('hurt', 'them'): 1,
#          ('hurt', 'in'): 2,
#          ('them', 'would'): 2,
#          ('them', 'hurt'): 1,
#          ('them', 'in'): 2,
#          ('them', 'the'): 4,
#          ('in', 'hurt'): 2,
#          ('in', 'them'): 2,
#          ('in', 'long'): 7,
#          ('the', 'them'): 4,
#          ('the', 'long'): 19,
#          ('the', '-'): 226,
#          ('long', 'in'): 7,
#          ('long', 'the'): 17,
#          ('long', '-'): 38,
#          ('long', 'run'): 2,
#          ('-', 'the'): 229,
#          ('-', 'long'): 38,
#          ('-', 'run'): 2,
#          ('-', ','): 167,
#          ('run', 'long'): 2,
#          ('run', '-'): 2,
#          ('run', ','): 3,
#          ('run', 'in'): 2,
#          (',', '-'): 165,
#          (',', 'run'): 3,
#          (',', 'in'): 587,
#          (',', 'the'): 1487,
#          ('in', 'run'): 2,
#          ('in', ','): 596,
#          ('in', 'short'): 11,
#          ('the', ','): 1496,
#          ('the', 'short'): 13,
#          ('short', 'in'): 12,
#          ('short', 'the'): 12,
#          ('short', '-'): 26,
#          ('short', 'term'): 30,
#          ('-', 'short'): 28,
#          ('-', 'term'): 60,
#          ('-', 'Tokyo'): 1,
#          ('term', 'short'): 29,
#          ('term', '-'): 60,
#          ('term', 'Tokyo'): 1,
#          ('term', "'"): 1,
#          ('Tokyo', '-'): 3,
#          ('Tokyo', 'term'): 1,
#          ('Tokyo', "'"): 5,
#          ('Tokyo', 's'): 5,
#          ("'", 'term'): 1,
#          ("'", 'Tokyo'): 5,
#          ("'", 'loss'): 1,
#          ('s', 'Tokyo'): 5,
#          ('s', 'loss'): 2,
#          ('s', 'might'): 1,
#          ('loss', "'"): 1,
#          ('loss', 's'): 2,
#          ('loss', 'might'): 1,
#          ('loss', 'be'): 3,
#          ('might', 's'): 1,
#          ('might', 'loss'): 1,
#          ('might', 'be'): 16,
#          ('might', 'their'): 1,
#          ('be', 'loss'): 3,
#          ('be', 'might'): 16,
#          ('be', 'their'): 1,
#          ('be', 'gain'): 3,
#          ('their', 'might'): 1,
#          ('their', 'be'): 1,
#          ('their', 'gain'): 2,
#          ('.', 'The'): 85,
#          ('S', 'Has'): 7,
#          ('.', 'Has'): 7,
#          ('.', 'said'): 41,
#          ('Has', 'S'): 7,
#          ('Has', '.'): 7,
#          ('Has', 'said'): 1,
#          ('Has', 'it'): 1,
#          ('said', '.'): 61,
#          ('said', 'Has'): 1,
#          ('said', 'it'): 671,
#          ('said', 'will'): 61,
#          ('it', 'Has'): 1,
#          ('it', 'said'): 861,
#          ('it', 'will'): 101,
#          ('it', 'impose'): 2,
#          ('will', 'said'): 83,
#          ('will', 'it'): 101,
#          ('will', 'impose'): 2,
#          ('will', '300'): 2,
#          ('impose', 'it'): 2,
#          ('impose', 'will'): 2,
#          ('impose', '300'): 1,
#          ('impose', 'mln'): 1,
#          ('300', 'will'): 2,
#          ('300', 'impose'): 1,
#          ('300', 'mln'): 20,
#          ('300', 'dlrs'): 14,
#          ('mln', 'impose'): 1,
#          ('mln', '300'): 20,
#          ('mln', 'dlrs'): 748,
#          ('mln', 'of'): 206,
#          ('dlrs', '300'): 13,
#          ('dlrs', 'mln'): 621,
#          ('dlrs', 'of'): 114,
#          ('dlrs', 'tariffs'): 2,
#          ('of', 'mln'): 207,
#          ('of', 'dlrs'): 116,
#          ('of', 'tariffs'): 8,
#          ('of', 'on'): 96,
#          ('tariffs', 'dlrs'): 2,
#          ('tariffs', 'of'): 7,
#          ('tariffs', 'on'): 23,
#          ('tariffs', 'imports'): 2,
#          ('on', 'of'): 96,
#          ('on', 'tariffs'): 23,
#          ('imports', 'tariffs'): 2,
#          ('imports', 'Japanese'): 10,
#          ('of', 'Japanese'): 35,
#          ('of', 'electronics'): 3,
#          ('Japanese', 'imports'): 10,
#          ('Japanese', 'of'): 35,
#          ('Japanese', 'electronics'): 2,
#          ('Japanese', 'goods'): 12,
#          ('electronics', 'of'): 3,
#          ('electronics', 'Japanese'): 2,
#          ('electronics', 'goods'): 2,
#          ('electronics', 'on'): 1,
#          ('goods', 'Japanese'): 12,
#          ('goods', 'electronics'): 2,
#          ('goods', 'on'): 6,
#          ('goods', 'April'): 1,
#          ('on', 'electronics'): 1,
#          ('on', 'goods'): 6,
#          ('on', 'April'): 59,
#          ('on', '17'): 9,
#          ('April', 'goods'): 1,
#          ('April', 'on'): 58,
#          ('April', '17'): 15,
#          ('April', ','): 148,
#          ('17', 'on'): 7,
#          ('17', 'April'): 10,
#          ('17', ','): 32,
#          ('17', 'in'): 7,
#          (',', 'April'): 158,
#          (',', '17'): 33,
#          (',', 'retaliation'): 1,
#          ('in', '17'): 7,
#          ('in', 'retaliation'): 6,
#          ('in', 'for'): 85,
#          ('retaliation', ','): 1,
#          ('retaliation', 'in'): 6,
#          ('retaliation', 'for'): 7,
#          ('retaliation', 'Japan'): 4,
#          ('for', 'in'): 85,
#          ('for', 'retaliation'): 7,
#          ('for', 'Japan'): 17,
#          ('for', "'"): 23,
#          ('Japan', 'retaliation'): 4,
#          ('Japan', 'for'): 16,
#          ('Japan', "'"): 70,
#          ('Japan', 's'): 69,
#          ("'", 'for'): 23,
#          ("'", 'Japan'): 70,
#          ("'", 'alleged'): 3,
#          ('s', 'Japan'): 75,
#          ('s', 'alleged'): 3,
#          ('s', 'failure'): 8,
#          ('alleged', "'"): 3,
#          ('alleged', 's'): 3,
#          ('alleged', 'failure'): 2,
#          ('alleged', 'to'): 3,
#          ('failure', 's'): 8,
#          ('failure', 'alleged'): 2,
#          ('failure', 'to'): 14,
#          ('failure', 'stick'): 1,
#          ('to', 'alleged'): 3,
#          ('to', 'failure'): 14,
#          ('to', 'stick'): 2,
#          ('to', 'to'): 124,
#          ('stick', 'failure'): 1,
#          ('stick', 'to'): 2,
#          ('stick', 'a'): 1,
#          ('to', 'a'): 476,
#          ('to', 'pact'): 6,
#          ('a', 'stick'): 1,
#          ('a', 'to'): 472,
#          ('a', 'pact'): 13,
#          ('a', 'not'): 49,
#          ('pact', 'to'): 5,
#          ('pact', 'a'): 13,
#          ('pact', 'not'): 2,
#          ('not', 'a'): 49,
#          ('not', 'pact'): 2,
#          ('not', 'to'): 87,
#          ('not', 'sell'): 3,
#          ('to', 'not'): 87,
#          ('to', 'sell'): 74,
#          ('to', 'semiconductors'): 1,
#          ('sell', 'not'): 3,
#          ('sell', 'to'): 74,
#          ('sell', 'semiconductors'): 1,
#          ('sell', 'on'): 1,
#          ('semiconductors', 'to'): 1,
#          ('semiconductors', 'sell'): 1,
#          ('semiconductors', 'on'): 1,
#          ('semiconductors', 'world'): 6,
#          ('on', 'sell'): 1,
#          ('on', 'semiconductors'): 1,
#          ('on', 'world'): 3,
#          ('on', 'markets'): 7,
#          ('world', 'semiconductors'): 6,
#          ('world', 'on'): 3,
#          ('world', 'markets'): 12,
#          ('world', 'at'): 7,
#          ('markets', 'on'): 5,
#          ('markets', 'world'): 10,
#          ('markets', 'at'): 6,
#          ('markets', 'below'): 2,
#          ('at', 'world'): 7,
#          ('at', 'markets'): 6,
#          ('at', 'below'): 6,
#          ('at', 'cost'): 5,
#          ('below', 'markets'): 2,
#          ('below', 'at'): 6,
#          ('below', 'cost'): 3,
#          ('below', '.'): 2,
#          ('estimates', 'Unofficial'): 1,
#          ('estimates', 'Japanese'): 1,
#          ('estimates', 'put'): 1,
#          ('estimates', 'the'): 10,
#          ('put', 'Japanese'): 1,
#          ('put', 'estimates'): 3,
#          ('put', 'the'): 8,
#          ('put', 'impact'): 1,
#          ('the', 'estimates'): 10,
#          ('the', 'put'): 11,
#          ('the', 'impact'): 34,
#          ('the', 'of'): 2458,
#          ('impact', 'put'): 1,
#          ('impact', 'the'): 35,
#          ('impact', 'of'): 12,
#          ('of', 'the'): 2437,
#          ('of', 'impact'): 12,
#          ('the', 'tariffs'): 25,
#          ('the', 'at'): 280,
#          ('tariffs', 'the'): 23,
#          ('tariffs', 'at'): 1,
#          ('tariffs', '10'): 2,
#          ('at', 'the'): 276,
#          ('at', 'tariffs'): 1,
#          ('at', '10'): 12,
#          ('at', 'billion'): 22,
#          ('10', 'tariffs'): 2,
#          ('10', 'at'): 12,
#          ('10', 'billion'): 16,
#          ('10', 'dlrs'): 36,
#          ('billion', 'at'): 22,
#          ('billion', '10'): 15,
#          ('billion', 'dlrs'): 339,
#          ('billion', 'and'): 34,
#          ('dlrs', '10'): 35,
#          ('dlrs', 'billion'): 300,
#          ('dlrs', 'and'): 76,
#          ('dlrs', 'spokesmen'): 1,
#          ('and', 'billion'): 34,
#          ('and', 'dlrs'): 76,
#          ('and', 'spokesmen'): 1,
#          ('and', 'for'): 113,
#          ('spokesmen', 'dlrs'): 1,
#          ('spokesmen', 'and'): 1,
#          ('spokesmen', 'for'): 1,
#          ('spokesmen', 'major'): 1,
#          ('for', 'and'): 112,
#          ('for', 'spokesmen'): 1,
#          ('for', 'major'): 15,
#          ('for', 'electronics'): 3,
#          ('major', 'spokesmen'): 1,
#          ('major', 'for'): 14,
#          ('major', 'electronics'): 2,
#          ('major', 'firms'): 1,
#          ('electronics', 'for'): 3,
#          ('electronics', 'major'): 2,
#          ('electronics', 'firms'): 1,
#          ('electronics', 'said'): 1,
#          ('firms', 'major'): 1,
#          ('firms', 'electronics'): 1,
#          ('firms', 'said'): 3,
#          ('firms', 'they'): 3,
#          ('said', 'electronics'): 1,
#          ('said', 'firms'): 3,
#          ('said', 'they'): 73,
#          ('said', 'would'): 62,
#          ('they', 'firms'): 3,
#          ('they', 'said'): 144,
#          ('they', 'would'): 25,
#          ('they', 'virtually'): 1,
#          ('would', 'said'): 77,
#          ('would', 'they'): 25,
#          ('would', 'virtually'): 1,
#          ('would', 'halt'): 3,
#          ('virtually', 'they'): 1,
#          ('virtually', 'would'): 1,
#          ('virtually', 'halt'): 1,
#          ('virtually', 'exports'): 1,
#          ('halt', 'would'): 3,
#          ('halt', 'virtually'): 1,
#          ('halt', 'exports'): 1,
#          ('halt', 'of'): 2,
#          ('exports', 'virtually'): 1,
#          ('exports', 'halt'): 1,
#          ('exports', 'of'): 24,
#          ('exports', 'products'): 2,
#          ('of', 'halt'): 2,
#          ('of', 'exports'): 28,
#          ('of', 'hit'): 2,
#          ('products', 'exports'): 2,
#          ('products', 'of'): 26,
#          ('products', 'hit'): 1,
#          ('products', 'by'): 5,
#          ('hit', 'of'): 2,
#          ('hit', 'products'): 1,
#          ('hit', 'by'): 11,
#          ('hit', 'the'): 9,
#          ('by', 'products'): 5,
#          ('by', 'hit'): 11,
#          ('by', 'the'): 335,
#          ('by', 'new'): 7,
#          ('the', 'hit'): 8,
#          ('the', 'by'): 336,
#          ('the', 'new'): 63,
#          ('the', 'taxes'): 3,
#          ('new', 'by'): 7,
#          ('new', 'the'): 64,
#          ('new', 'taxes'): 5,
#          ('new', '.'): 16,
#          ('wouldn', '"'): 2,
#          ('wouldn', 'We'): 2,
#          ('wouldn', "'"): 6,
#          ('wouldn', 't'): 6,
#          ("'", 'We'): 22,
#          ("'", 'wouldn'): 6,
#          ("'", 't'): 75,
#          ("'", 'be'): 7,
#          ('t', 'wouldn'): 6,
#          ('t', "'"): 75,
#          ('t', 'be'): 5,
#          ('t', 'able'): 1,
#          ('be', "'"): 7,
#          ('be', 't'): 5,
#          ('be', 'able'): 21,
#          ('be', 'to'): 450,
#          ('able', 't'): 1,
#          ('able', 'be'): 21,
#          ('able', 'to'): 31,
#          ('able', 'do'): 4,
#          ('to', 'be'): 450,
#          ('to', 'able'): 31,
#          ('to', 'do'): 26,
#          ('to', 'business'): 14,
#          ('do', 'able'): 4,
#          ('do', 'to'): 25,
#          ('do', 'business'): 4,
#          ('do', ',"'): 10,
#          ('business', 'to'): 14,
#          ('business', 'do'): 4,
#          ('business', ',"'): 6,
#          ('business', 'said'): 8,
#          (',"', 'do'): 10,
#          (',"', 'business'): 6,
#          (',"', 'said'): 424,
#          (',"', 'a'): 32,
#          ('said', 'business'): 7,
#          ('said', ',"'): 167,
#          ('said', 'a'): 144,
#          ('said', 'spokesman'): 45,
#          ('a', ',"'): 32,
#          ('a', 'said'): 180,
#          ('a', 'spokesman'): 45,
#          ('a', 'for'): 225,
#          ('spokesman', 'said'): 72,
#          ('spokesman', 'a'): 43,
#          ('spokesman', 'for'): 19,
#          ('spokesman', 'leading'): 1,
#          ('for', 'a'): 225,
#          ('for', 'spokesman'): 32,
#          ('for', 'leading'): 1,
#          ('for', 'Japanese'): 6,
#          ('leading', 'spokesman'): 1,
#          ('leading', 'for'): 1,
#          ('leading', 'Japanese'): 1,
#          ('leading', 'electronics'): 1,
#          ('Japanese', 'for'): 5,
#          ('Japanese', 'leading'): 1,
#          ('Japanese', 'firm'): 1,
#          ('electronics', 'leading'): 1,
#          ('electronics', 'firm'): 2,
#          ('electronics', 'Matsushita'): 1,
#          ('firm', 'Japanese'): 1,
#          ('firm', 'electronics'): 2,
#          ('firm', 'Matsushita'): 1,
#          ('firm', 'Electric'): 1,
#          ('Matsushita', 'electronics'): 1,
#          ('Matsushita', 'firm'): 1,
#          ('Matsushita', 'Electric'): 1,
#          ('Matsushita', 'Industrial'): 1,
#          ('Electric', 'firm'): 1,
#          ('Electric', 'Matsushita'): 1,
#          ('Electric', 'Industrial'): 1,
#          ('Electric', 'Co'): 6,
#          ('Industrial', 'Matsushita'): 1,
#          ('Industrial', 'Electric'): 1,
#          ('Industrial', 'Co'): 1,
#          ('Industrial', 'Ltd'): 2,
#          ('Co', 'Electric'): 6,
#          ('Co', 'Industrial'): 1,
#          ('Co', 'Ltd'): 31,
#          ('Co', '&'): 47,
#          ('Ltd', 'Industrial'): 2,
#          ('Ltd', 'Co'): 30,
#          ('Ltd', '&'): 58,
#          ('Ltd', 'lt'): 58,
#          ('&', 'Co'): 47,
#          ('&', 'Ltd'): 58,
#          ('&', 'lt'): 1273,
#          ('&', ';'): 1272,
#          ('lt', 'Ltd'): 58,
#          ('lt', '&'): 1462,
#          ('lt', ';'): 1462,
#          ('lt', 'MC'): 1,
#          (';', '&'): 1496,
#          (';', 'lt'): 1497,
#          (';', 'MC'): 1,
#          (';', '.'): 436,
#          ('MC', 'lt'): 1,
#          ('MC', ';'): 1,
#          ('MC', '.'): 1,
#          ('MC', 'T'): 1,
#          ('.', ';'): 436,
#          ('.', 'MC'): 1,
#          ('.', 'T'): 27,
#          ('.', '>.'): 23,
#          ('the', '"'): 111,
#          ('the', 'If'): 3,
#          ('the', 'remain'): 4,
#          ('tariffs', 'If'): 1,
#          ('tariffs', 'remain'): 2,
#          ('tariffs', 'in'): 2,
#          ('remain', 'the'): 4,
#          ('remain', 'tariffs'): 2,
#          ('remain', 'in'): 8,
#          ('remain', 'place'): 1,
#          ('in', 'tariffs'): 2,
#          ('in', 'remain'): 8,
#          ('in', 'place'): 10,
#          ('place', 'remain'): 1,
#          ('place', 'in'): 5,
#          ('place', 'for'): 2,
#          ('place', 'any'): 3,
#          ('for', 'place'): 2,
#          ('for', 'any'): 9,
#          ('for', 'length'): 1,
#          ('any', 'place'): 3,
#          ('any', 'for'): 9,
#          ('any', 'length'): 1,
#          ('any', 'of'): 27,
#          ('length', 'for'): 1,
#          ('length', 'any'): 1,
#          ('length', 'of'): 1,
#          ('length', 'time'): 1,
#          ('of', 'any'): 27,
#          ('of', 'length'): 1,
#          ('of', 'time'): 27,
#          ('of', 'beyond'): 2,
#          ('time', 'length'): 1,
#          ('time', 'of'): 24,
#          ('time', 'beyond'): 1,
#          ('time', 'a'): 21,
#          ('beyond', 'of'): 2,
#          ('beyond', 'time'): 1,
#          ('beyond', 'a'): 1,
#          ('beyond', 'few'): 1,
#          ('a', 'time'): 22,
#          ('a', 'beyond'): 1,
#          ('a', 'few'): 12,
#          ('a', 'months'): 2,
#          ('few', 'beyond'): 1,
#          ('few', 'a'): 12,
#          ('few', 'months'): 8,
#          ('few', 'it'): 1,
#          ('months', 'a'): 2,
#          ('months', 'few'): 7,
#          ('months', 'it'): 2,
#          ('months', 'will'): 1,
#          ('it', 'few'): 1,
#          ('it', 'months'): 2,
#          ('it', 'mean'): 1,
#          ('will', 'months'): 1,
#          ('will', 'mean'): 1,
#          ('will', 'the'): 154,
#          ('mean', 'it'): 1,
#          ('mean', 'will'): 1,
#          ('mean', 'the'): 6,
#          ('mean', 'complete'): 1,
#          ('the', 'will'): 159,
#          ('the', 'mean'): 6,
#          ('the', 'complete'): 6,
#          ('the', 'erosion'): 1,
#          ('complete', 'mean'): 1,
#          ('complete', 'the'): 6,
#          ('complete', 'erosion'): 1,
#          ('complete', 'of'): 3,
#          ('erosion', 'the'): 1,
#          ('erosion', 'complete'): 1,
#          ('erosion', 'of'): 2,
#          ('erosion', 'exports'): 1,
#          ('of', 'complete'): 3,
#          ('of', 'erosion'): 2,
#          ('of', '('): 33,
#          ('exports', 'erosion'): 1,
#          ('exports', '('): 1,
#          ('(', 'of'): 32,
#          ('(', 'exports'): 1,
#          ('(', 'goods'): 1,
#          ('of', 'goods'): 21,
#          ('of', 'subject'): 4,
#          ('goods', '('): 1,
#          ('goods', 'of'): 21,
#          ('goods', 'subject'): 1,
#          ('goods', 'to'): 7,
#          ('subject', 'of'): 4,
#          ('subject', 'goods'): 1,
#          ('subject', 'to'): 66,
#          ('subject', 'tariffs'): 1,
#          ('to', 'goods'): 8,
#          ('to', 'subject'): 66,
#          ('to', 'tariffs'): 14,
#          ('to', ')'): 18,
#          ('tariffs', 'subject'): 1,
#          ('tariffs', 'to'): 13,
#          ('tariffs', ')'): 3,
#          (')', 'to'): 18,
#          (')', 'tariffs'): 3,
#          (')', 'the'): 35,
#          ('to', 'the'): 1087,
#          ('to', 'U'): 52,
#          ('the', ')'): 35,
#          ('the', 'to'): 1103,
#          ('U', 'to'): 54,
#          ('.', '.,"'): 4,
#          ('S', '.,"'): 4,
#          ('S', 'said'): 14,
#          ('.,"', '.'): 4,
#          ('.,"', 'S'): 4,
#          ('.,"', 'said'): 5,
#          ('.,"', 'Tom'): 1,
#          ('said', 'S'): 13,
#          ('said', '.,"'): 4,
#          ('said', 'Tom'): 2,
#          ('said', 'Murtha'): 1,
#          ('Tom', '.,"'): 1,
#          ('Tom', 'said'): 2,
#          ('Tom', 'Murtha'): 1,
#          ('Tom', ','): 2,
#          ('Murtha', 'said'): 1,
#          ('Murtha', 'Tom'): 1,
#          ('Murtha', ','): 1,
#          ('Murtha', 'a'): 1,
#          (',', 'Tom'): 2,
#          (',', 'Murtha'): 1,
#          (',', 'a'): 604,
#          (',', 'stock'): 55,
#          ('a', 'Murtha'): 1,
#          ('a', ','): 601,
#          ('a', 'stock'): 23,
#          ('a', 'analyst'): 4,
#          ('stock', ','): 55,
#          ('stock', 'a'): 23,
#          ('stock', 'analyst'): 1,
#          ('stock', 'at'): 9,
#          ('analyst', 'a'): 4,
#          ('analyst', 'stock'): 1,
#          ('analyst', 'at'): 5,
#          ('analyst', 'the'): 3,
#          ('at', 'stock'): 9,
#          ('at', 'analyst'): 5,
#          ('at', 'Tokyo'): 4,
#          ('the', 'analyst'): 1,
#          ('the', 'Tokyo'): 9,
#          ('the', 'office'): 9,
#          ('Tokyo', 'at'): 4,
#          ('Tokyo', 'the'): 9,
#          ('Tokyo', 'office'): 1,
#          ('Tokyo', 'of'): 7,
#          ('office', 'the'): 9,
#          ('office', 'Tokyo'): 1,
#          ('office', 'of'): 3,
#          ('office', 'broker'): 1,
#          ('of', 'Tokyo'): 7,
#          ('of', 'office'): 3,
#          ('of', 'broker'): 3,
#          ('of', '&'): 29,
#          ('broker', 'office'): 1,
#          ('broker', 'of'): 3,
#          ('broker', '&'): 1,
#          ('broker', 'lt'): 1,
#          ('&', 'of'): 29,
#          ('&', 'broker'): 1,
#          ('lt', 'broker'): 1,
#          ('lt', 'James'): 1,
#          (';', 'James'): 1,
#          (';', 'Capel'): 1,
#          ('James', 'lt'): 1,
#          ('James', ';'): 1,
#          ('James', 'Capel'): 2,
#          ('James', 'and'): 4,
#          ('Capel', ';'): 1,
#          ('Capel', 'James'): 2,
#          ('Capel', 'and'): 2,
#          ('Capel', 'Co'): 2,
#          ('and', 'James'): 4,
#          ('and', 'Capel'): 2,
#          ('and', 'Co'): 78,
#          ('and', '>.'): 2,
#          (',', 'In'): 63,
#          (',', 'Taiwan'): 10,
#          ('businessmen', 'Taiwan'): 1,
#          ('and', 'are'): 36,
#          ('officials', 'are'): 3,
#          ('officials', 'also'): 1,
#          ('are', 'and'): 36,
#          ('are', 'officials'): 4,
#          ('are', 'also'): 14,
#          ('are', 'worried'): 1,
#          ('also', 'officials'): 4,
#          ('also', 'are'): 14,
#          ('also', 'worried'): 2,
#          ('also', '.'): 14,
#          ('are', '"'): 30,
#          ('are', 'We'): 13,
#          ('are', 'aware'): 1,
#          ('are', 'of'): 14,
#          ('aware', 'We'): 1,
#          ('aware', 'are'): 1,
#          ('aware', 'of'): 5,
#          ('aware', 'the'): 3,
#          ('of', 'are'): 14,
#          ('of', 'aware'): 5,
#          ('of', 'seriousness'): 4,
#          ('the', 'aware'): 3,
#          ('the', 'seriousness'): 5,
#          ('seriousness', 'of'): 4,
#          ('seriousness', 'the'): 5,
#          ('of', 'U'): 112,
#          ('U', 'of'): 113,
#          ('Japan', 'Threat'): 1,
#          ('Japan', 'because'): 6,
#          ('Japan', 'it'): 8,
#          ('because', 'against'): 1,
#          ('because', 'Japan'): 6,
#          ('because', 'it'): 21,
#          ('because', 'serves'): 1,
#          ('it', 'Japan'): 7,
#          ('it', 'because'): 21,
#          ('it', 'serves'): 1,
#          ('it', 'as'): 19,
#          ('serves', 'because'): 1,
#          ('serves', 'it'): 1,
#          ('serves', 'as'): 1,
#          ('serves', 'a'): 1,
#          ('as', 'it'): 19,
#          ('as', 'serves'): 1,
#          ('as', 'a'): 139,
#          ('as', 'warning'): 1,
#          ('a', 'serves'): 1,
#          ('a', 'as'): 139,
#          ('a', 'warning'): 3,
#          ('warning', 'as'): 1,
#          ('warning', 'a'): 3,
#          ('warning', 'to'): 1,
#          ('warning', 'us'): 1,
#          ('to', 'warning'): 1,
#          ('to', 'us'): 10,
#          ('to', ',"'): 13,
#          ('us', 'warning'): 1,
#          ('us', 'to'): 10,
#          ('us', ',"'): 2,
#          ('us', 'said'): 1,
#          (',"', 'to'): 13,
#          (',"', 'us'): 2,
#          ('said', 'us'): 1,
#          ('said', 'senior'): 2,
#          ('a', 'senior'): 8,
#          ('a', 'Taiwanese'): 2,
#          ('senior', 'said'): 2,
#          ('senior', 'a'): 8,
#          ('senior', 'Taiwanese'): 1,
#          ('senior', 'trade'): 1,
#          ('Taiwanese', 'a'): 2,
#          ('Taiwanese', 'senior'): 1,
#          ('Taiwanese', 'trade'): 1,
#          ('Taiwanese', 'official'): 1,
#          ...})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):

    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1

    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75

    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1

    return result

# %%
from itertools import combinations_with_replacement

X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass

    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):

    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []

    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]

    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)

    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])

        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])

    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
batch_size = 2
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

# %%
x
# Out:
# array([[11731],
#        [ 1366]])

# %%
y
# Out:
# array([[11175],
#        [  349]])

# %%
cooc
# Out:
# array([[4.30406509],
#        [2.19722458]])

# %%
weighting
# Out:
# array([[0.79785467],
#        [0.16431677]])

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
class Glove(nn.Module):

    def __init__(self, voc_size, emb_size, word2index):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)

        self.center_bias       = nn.Embedding(voc_size, 1)
        self.outside_bias      = nn.Embedding(voc_size, 1)

        self.word2index        = word2index

    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)

        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)

        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)

        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)

        return torch.sum(loss)

    def get_embed(self, word):
      word2index = self.word2index
      try:
        index = word2index[word]
      except:
        index = word2index['<UNK>']

      word = torch.LongTensor([index]).to(device)

      embed_c = self.center_embedding(word)
      embed_o = self.outside_embedding(word)
      embed   = (embed_c + embed_o) / 2

      return embed[0][0].item(), embed[0][1].item()

# %%
#test our system
voc_size = len(vocab)
emb_size = 2
model = Glove(voc_size, emb_size, word2index)

# %%
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %%
loss
# Out:
# tensor(21.1065, grad_fn=<SumBackward0>)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = Glove(voc_size, embedding_size, word2index).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_time, elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 1000
total_start_time = time.time()
for epoch in range(num_epochs):

    start = time.time()

    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]

    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)

    loss.backward()
    optimizer.step()

    end = time.time()

    total, epoch_mins, epoch_secs = epoch_time(start, end)

    if (epoch + 1) % 100 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s")

total_end_time = time.time()
total_time, mins, secs = epoch_time(total_start_time, total_end_time)
# Out:
# Epoch: 100 | cost: 9.174536 | time: 0m 0s
# Epoch: 200 | cost: 36.420441 | time: 0m 0s
# Epoch: 300 | cost: 319.926636 | time: 0m 0s
# Epoch: 400 | cost: 37.827198 | time: 0m 0s
# Epoch: 500 | cost: 31.364248 | time: 0m 0s
# Epoch: 600 | cost: 144.001297 | time: 0m 0s
# Epoch: 700 | cost: 21.758560 | time: 0m 0s
# Epoch: 800 | cost: 89.913231 | time: 0m 0s
# Epoch: 900 | cost: 87.280876 | time: 0m 0s
# Epoch: 1000 | cost: 3.063797 | time: 0m 0s

# %%
# print total train loss and total training time
print(f"Total train loss: {loss:.6f}")
print(f"Total training time: {total_time:.2f} seconds")
# Out:
# Total train loss: 3.063797
# Total training time: 251.27 seconds

# %% [markdown]
# ## 6. Plotting the embeddings

# %%
#list of vocabs
vocab[:10]
# Out:
# ['ending',
#  'JORDAN',
#  'Sight',
#  'impact',
#  'scratch',
#  'well',
#  'shared',
#  'graphics',
#  'Foothill',
#  'Baldwin']

# %%
word = vocab[0]

# %% [markdown]
# ## 7. Save model

# %%
torch.save(model.state_dict(), '../content/app/code/models/glove.pt')

# %%
import pickle

glove_args = {
    'word2index': word2index,
    'voc_size': voc_size,
    'emb_size': emb_size
}

pickle.dump(glove_args, open('../content/app/code/models/glove.pkl', 'wb'))

# %%
load_glove_args = pickle.load(open('../content/app/code/models/glove.pkl', 'rb'))
load_model = Glove(**load_glove_args).to(device)
load_model.load_state_dict(torch.load('../content/app/code/models/glove.pt'))
# Out:
# <ipython-input-61-caed6fa8926c>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   load_model.load_state_dict(torch.load('../content/app/code/models/glove.pt'))
# <All keys matched successfully>

# %%
load_model.get_embed('impact')
# Out:
# (-0.06003697216510773, 0.8854387998580933)
